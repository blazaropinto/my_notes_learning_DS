# %%
#imports
import pandas as pd
import numpy as np

# %%
#import dataframe with relation country/regions from csv downloaded from http://www.fao.org/faostat/en/#definitions
region_country = pd.read_csv('original/FAOSTAT_data_2-24-2021.csv', usecols=['Country Group', 'Country'])
regions = list(region_country['Country Group'].unique())
europecountries = list(region_country[region_country['Country Group'] == 'Europe']['Country'])

# %% [markdown]
# # Crops - production

# %% [markdown]
# **1. all data crops**

# %%
#import original dataset from csv downloaded from http://www.fao.org/faostat/en/#data/QC
df = pd.read_csv('original/Production_Crops_E_All_Data.csv', encoding='latin1')
original_df = pd.DataFrame(df) #this is to be sure the original df (not just the location) is saved
original_df.head()
# Out:
#    Area Code         Area  Item Code                              Item  \
# 0          2  Afghanistan        221               Almonds, with shell
# 1          2  Afghanistan        221               Almonds, with shell
# 2          2  Afghanistan        221               Almonds, with shell
# 3          2  Afghanistan        711  Anise, badian, fennel, coriander
# 4          2  Afghanistan        711  Anise, badian, fennel, coriander
#
#    Element Code         Element    Unit  Y1961 Y1961F  Y1962  ...    Y2015  \
# 0          5312  Area harvested      ha    NaN    NaN    NaN  ...  14676.0
# 1          5419           Yield   hg/ha    NaN    NaN    NaN  ...  16521.0
# 2          5510      Production  tonnes    NaN    NaN    NaN  ...  24246.0
# 3          5312  Area harvested      ha    NaN      M    NaN  ...  25000.0
# 4          5419           Yield   hg/ha    NaN    NaN    NaN  ...   7200.0
#
#    Y2015F    Y2016  Y2016F    Y2017  Y2017F    Y2018  Y2018F    Y2019  Y2019F
# 0     NaN  19481.0     NaN  19793.0     NaN  20053.0     NaN  29203.0     NaN
# 1      Fc  16859.0      Fc  13788.0      Fc  17161.0      Fc  13083.0      Fc
# 2     NaN  32843.0     NaN  27291.0     NaN  34413.0     NaN  38205.0     NaN
# 3       F  25787.0      Im  28398.0      Im  26725.0      Im  27562.0      Im
# 4      Fc   6982.0      Fc   6863.0      Fc   6898.0      Fc   6903.0      Fc
#
# [5 rows x 125 columns]

# %%
#check i those colums are redundant
print('Number of Area codes:', 
      len(df['Area Code'].unique()))

print('Number of Areas:',
      len(df.Area.unique()))
# Out:
# Number of Area codes: 246
# Number of Areas: 246

# %%
#remove redundant/unuseful columns for simple analysis, remove 'Y' from years
cols=[]

for col in df.columns:
    if col.endswith('F'):
        df.drop(columns=[col], inplace= True)
    elif col.endswith('Code'):
        df.drop(columns=[col], inplace= True)
    elif col.startswith('Y'):
        cols.append(int(col.replace('Y','')))
    else:
        cols.append(col)
        
df.columns = cols
df.head()
# Out:
#           Area                              Item         Element    Unit  \
# 0  Afghanistan               Almonds, with shell  Area harvested      ha
# 1  Afghanistan               Almonds, with shell           Yield   hg/ha
# 2  Afghanistan               Almonds, with shell      Production  tonnes
# 3  Afghanistan  Anise, badian, fennel, coriander  Area harvested      ha
# 4  Afghanistan  Anise, badian, fennel, coriander           Yield   hg/ha
#
#    1961  1962  1963  1964  1965  1966  ...     2010     2011     2012  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  11210.0  13469.0  13490.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  49955.0  45000.0  45960.0
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...  56000.0  60611.0  62000.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...  17000.0  19500.0  18500.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...   6000.0   6414.0   6757.0
#
#       2013     2014     2015     2016     2017     2018     2019
# 0  14114.0  13703.0  14676.0  19481.0  19793.0  20053.0  29203.0
# 1  29910.0  19996.0  16521.0  16859.0  13788.0  17161.0  13083.0
# 2  42215.0  27400.0  24246.0  32843.0  27291.0  34413.0  38205.0
# 3  18500.0  30000.0  25000.0  25787.0  28398.0  26725.0  27562.0
# 4   6757.0   7167.0   7200.0   6982.0   6863.0   6898.0   6903.0
#
# [5 rows x 63 columns]

# %%
dftemp = df.drop(columns=['Area', 'Item', 'Element', 'Unit'])
# add new column for yearly avg
df['yearly_average_1961-2019'] = dftemp.mean(axis=1)
# add new column for std of the values used for the mean, be careful to use dataframe without new added column!
df['std_1961-2019'] = dftemp.std(axis=1) 
df.head()
# Out:
#           Area                              Item         Element    Unit  \
# 0  Afghanistan               Almonds, with shell  Area harvested      ha
# 1  Afghanistan               Almonds, with shell           Yield   hg/ha
# 2  Afghanistan               Almonds, with shell      Production  tonnes
# 3  Afghanistan  Anise, badian, fennel, coriander  Area harvested      ha
# 4  Afghanistan  Anise, badian, fennel, coriander           Yield   hg/ha
#
#    1961  1962  1963  1964  1965  1966  ...     2012     2013     2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  13490.0  14114.0  13703.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  45960.0  29910.0  19996.0
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...  62000.0  42215.0  27400.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...  18500.0  18500.0  30000.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...   6757.0   6757.0   7167.0
#
#       2015     2016     2017     2018     2019  yearly_average_1961-2019  \
# 0  14676.0  19481.0  19793.0  20053.0  29203.0               8951.688889
# 1  16521.0  16859.0  13788.0  17161.0  13083.0              20382.704545
# 2  24246.0  32843.0  27291.0  34413.0  38205.0              18990.933333
# 3  25000.0  25787.0  28398.0  26725.0  27562.0              12087.823529
# 4   7200.0   6982.0   6863.0   6898.0   6903.0               6589.647059
#
#    std_1961-2019
# 0    5452.496458
# 1    8979.791670
# 2   15382.579516
# 3   10162.350770
# 4     485.336302
#
# [5 rows x 65 columns]

# %%
#save all data in 'easy-to-use' format
df.to_csv('clean/all_data_crops.csv')

# %% [markdown]
# #### 2. stack dataframe of all data crops

# %%
alldataoveryears = df.set_index(['Area', 'Item', 'Element', 'Unit']) \
        .drop(columns=['yearly_average_1961-2019', 'std_1961-2019']).stack() \
        .reset_index()
alldataoveryears = alldataoveryears.rename(columns={0:'Value', 'level_4': 'Year'})  # rename specific column
alldataoveryears.to_csv('clean/all_data_crops_over_years.csv')
alldataoveryears.head()
# Out:
#           Area                 Item         Element Unit  Year   Value
# 0  Afghanistan  Almonds, with shell  Area harvested   ha  1975     0.0
# 1  Afghanistan  Almonds, with shell  Area harvested   ha  1976  5900.0
# 2  Afghanistan  Almonds, with shell  Area harvested   ha  1977  6000.0
# 3  Afghanistan  Almonds, with shell  Area harvested   ha  1978  6000.0
# 4  Afghanistan  Almonds, with shell  Area harvested   ha  1979  6000.0

# %% [markdown]
# **3. data crops for europe countries**

# %%
eu_data_crops = df[df.Area.isin(europecountries)].reset_index(drop=True) #when subsenting and non informative index, drop it
eu_data_crops = eu_data_crops.round(2)  #round all values in df to 2 decimal places
eu_data_crops.head()
# Out:
#       Area      Item         Element    Unit     1961    1962    1963    1964  \
# 0  Albania    Apples  Area harvested      ha      NaN     NaN     NaN     NaN
# 1  Albania    Apples           Yield   hg/ha      NaN     NaN     NaN     NaN
# 2  Albania    Apples      Production  tonnes  10004.0  8039.0  7931.0  8498.0
# 3  Albania  Apricots  Area harvested      ha      NaN     NaN     NaN     NaN
# 4  Albania  Apricots           Yield   hg/ha      NaN     NaN     NaN     NaN
#
#      1965    1966  ...      2012      2013      2014      2015      2016  \
# 0     NaN     NaN  ...    3719.0    3838.0    3863.0    4008.0    4230.0
# 1     NaN     NaN  ...  191718.0  197316.0  212426.0  228882.0  240028.0
# 2  8000.0  9000.0  ...   71300.0   75730.0   82060.0   91736.0  101532.0
# 3     NaN     NaN  ...     301.0     315.0     320.0     331.0     326.0
# 4     NaN     NaN  ...  147176.0  139683.0  129375.0  152417.0  159325.0
#
#        2017      2018      2019  yearly_average_1961-2019  std_1961-2019
# 0    4346.0    4294.0    4407.0                   3339.63        1274.72
# 1  221671.0  252387.0  240374.0                  99296.09       74287.41
# 2   96338.0  108375.0  105933.0                  26934.61       28529.30
# 3     326.0     337.0     341.0                    388.60         106.93
# 4  154601.0  152493.0  142962.0                  68517.34       55400.62
#
# [5 rows x 65 columns]

# %%
eu_data_crops.to_csv('clean/eu_data_crops.csv')

# %% [markdown]
# #### 4. stacked data crops for europe countries

# %%
eudataoveryears = alldataoveryears[alldataoveryears.Area.isin(europecountries)].reset_index(drop=True)
eudataoveryears.to_csv('clean/all_data_crops_over_years.csv')
display(eudataoveryears.shape, eudataoveryears.head())
# Out:
# (337321, 6)
#       Area    Item         Element Unit  Year   Value
# 0  Albania  Apples  Area harvested   ha  1985  3600.0
# 1  Albania  Apples  Area harvested   ha  1986  3000.0
# 2  Albania  Apples  Area harvested   ha  1987  3000.0
# 3  Albania  Apples  Area harvested   ha  1988  2800.0
# 4  Albania  Apples  Area harvested   ha  1989  3500.0

# %% [markdown]
# #### ** 5. production**

# %%
#dataframe with only production data
production = (df[df.Element == 'Production']).drop(columns=['Element'])

#check if unit always tonnes
production.Unit.unique()
# Out:
# array(['tonnes'], dtype=object)

# %%
#drop 'unit' column and save
production = production.drop(columns=['Unit'])
production.to_csv('clean/production.csv')

# %% [markdown]
# #### **6. apple production over the years**

# %%
production.head()
# Out:
#            Area                              Item      1961      1962  \
# 2   Afghanistan               Almonds, with shell       NaN       NaN
# 5   Afghanistan  Anise, badian, fennel, coriander       NaN       NaN
# 8   Afghanistan                            Apples   15100.0   15100.0
# 11  Afghanistan                          Apricots   32000.0   32000.0
# 14  Afghanistan                            Barley  378000.0  378000.0
#
#         1963      1964      1965      1966      1967      1968  ...      2012  \
# 2        NaN       NaN       NaN       NaN       NaN       NaN  ...   62000.0
# 5        NaN       NaN       NaN       NaN       NaN       NaN  ...   12500.0
# 8    15100.0   18400.0   20400.0   22800.0   27600.0   27900.0  ...   70000.0
# 11   32000.0   39200.0   43400.0   48400.0   58700.0   59400.0  ...   83500.0
# 14  378000.0  380000.0  380000.0  375000.0  357000.0  361000.0  ...  504000.0
#
#         2013      2014      2015      2016      2017      2018      2019  \
# 2    42215.0   27400.0   24246.0   32843.0   27291.0   34413.0   38205.0
# 5    12500.0   21500.0   18000.0   18005.0   19490.0   18436.0   19025.0
# 8    78597.0   89403.0   89733.0  140903.0  175000.0  217192.0  250324.0
# 11   90000.0   90000.0   87686.0   17894.0  131816.0  109086.0  129363.0
# 14  514000.0  521000.0  403000.0  301856.0   94995.0   56781.0  123576.0
#
#     yearly_average_1961-2019  std_1961-2019
# 2               18990.933333   15382.579516
# 5                7933.705882    6920.749305
# 8               42550.508475   47077.857625
# 11              52387.457627   22188.061657
# 14             303493.355932  103313.817707
#
# [5 rows x 63 columns]

# %%
#dataframe for apple production over this period in all countries
apples = production[production.Item == 'Apples']\
    .set_index('Area').drop(columns=['Item', 'yearly_average_1961-2019', 'std_1961-2019']).transpose()
apples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1961 to 2019
# Columns: 131 entries, Afghanistan to Net Food Importing Developing Countries
# dtypes: float64(131)
# memory usage: 60.8+ KB

# %%
apples.to_csv('clean/apples.csv')
apples.head()
# Out:
# Area  Afghanistan  Albania  Algeria  Argentina  Armenia  Australia   Austria  \
# 1961      15100.0  10004.0  15400.0   415000.0      NaN   295034.0  456000.0
# 1962      15100.0   8039.0  14000.0   397000.0      NaN   326282.0  431000.0
# 1963      15100.0   7931.0  13000.0   474000.0      NaN   349571.0  436000.0
# 1964      18400.0   8498.0  12441.0   371000.0      NaN   367397.0  447000.0
# 1965      20400.0   8000.0  13151.0   544000.0      NaN   360002.0  222000.0
#
# Area  Azerbaijan  Belarus  Belgium  ...  Western Europe   Oceania  \
# 1961         NaN      NaN      NaN  ...       4142800.0  369434.0
# 1962         NaN      NaN      NaN  ...       8391400.0  419772.0
# 1963         NaN      NaN      NaN  ...       6006600.0  433571.0
# 1964         NaN      NaN      NaN  ...       6310800.0  476797.0
# 1965         NaN      NaN      NaN  ...       6156400.0  462902.0
#
# Area  Australia and New Zealand  European Union (28)  European Union (27)  \
# 1961                   369434.0            8362520.0            8023520.0
# 1962                   419772.0           12509286.0           11926286.0
# 1963                   433571.0           10951698.0           10406698.0
# 1964                   476797.0           11735102.0           11082102.0
# 1965                   462902.0           10717120.0           10188120.0
#
# Area  Least Developed Countries  Land Locked Developing Countries  \
# 1961                    26100.0                           35300.0
# 1962                    26200.0                           35500.0
# 1963                    26300.0                           35451.0
# 1964                    30650.0                           38907.0
# 1965                    32700.0                           42220.0
#
# Area  Small Island Developing States  Low Income Food Deficit Countries  \
# 1961                           530.0                           310300.0
# 1962                           535.0                           303400.0
# 1963                           535.0                           278700.0
# 1964                           540.0                           250100.0
# 1965                           540.0                           243200.0
#
# Area  Net Food Importing Developing Countries
# 1961                                 126230.0
# 1962                                 121556.0
# 1963                                 137660.0
# 1964                                 156225.0
# 1965                                 156438.0
#
# [5 rows x 131 columns]

# %% [markdown]
# ### **7. apple production over the years in europe**

# %%
apples_europe = pd.DataFrame (apples)

for col in apples_europe:
    if col not in europecountries:
        apples_europe.drop(columns=col, inplace=True)

print(len(apples_europe.columns))
apples_europe.to_csv('clean/apples_eu.csv')
apples_europe.head()
# Out:
# 43
# Area  Albania   Austria  Belarus  Belgium  Belgium-Luxembourg  \
# 1961  10004.0  456000.0      NaN      NaN            132000.0
# 1962   8039.0  431000.0      NaN      NaN            145000.0
# 1963   7931.0  436000.0      NaN      NaN            135000.0
# 1964   8498.0  447000.0      NaN      NaN            189200.0
# 1965   8000.0  222000.0      NaN      NaN            176000.0
#
# Area  Bosnia and Herzegovina  Bulgaria  Croatia  Czechia  Czechoslovakia  ...  \
# 1961                     NaN  272703.0      NaN      NaN        117138.0  ...
# 1962                     NaN  350612.0      NaN      NaN        130763.0  ...
# 1963                     NaN  289695.0      NaN      NaN        133985.0  ...
# 1964                     NaN  364126.0      NaN      NaN        158662.0  ...
# 1965                     NaN  299404.0      NaN      NaN         91630.0  ...
#
# Area  Serbia and Montenegro  Slovakia  Slovenia     Spain    Sweden  \
# 1961                    NaN       NaN       NaN  385500.0  100000.0
# 1962                    NaN       NaN       NaN  274500.0  161000.0
# 1963                    NaN       NaN       NaN  480700.0  136000.0
# 1964                    NaN       NaN       NaN  321600.0  183000.0
# 1965                    NaN       NaN       NaN  446800.0  115000.0
#
# Area  Switzerland  Ukraine  \
# 1961     269800.0      NaN
# 1962     480400.0      NaN
# 1963     359600.0      NaN
# 1964     389600.0      NaN
# 1965     255400.0      NaN
#
# Area  United Kingdom of Great Britain and Northern Ireland       USSR  \
# 1961                                           339000.0     1744000.0
# 1962                                           583000.0     1865000.0
# 1963                                           545000.0     2382000.0
# 1964                                           653000.0     2639000.0
# 1965                                           529000.0     2716000.0
#
# Area  Yugoslav SFR
# 1961      343000.0
# 1962      177000.0
# 1963      280000.0
# 1964      159000.0
# 1965      135000.0
#
# [5 rows x 43 columns]

# %% [markdown]
# #### 8. stacked strawberry data over decades in europe

# %%
strawberries = eudataoveryears[eudataoveryears.Item == 'Strawberries'] \
             .reset_index(drop=True).drop(columns=['Item'])
display(strawberries.head(), strawberries.Area.unique())
# Out:
#       Area         Element   Unit  Year     Value
# 0  Albania  Area harvested     ha  2017     102.0
# 1  Albania  Area harvested     ha  2018     111.0
# 2  Albania  Area harvested     ha  2019     121.0
# 3  Albania           Yield  hg/ha  2017  498922.0
# 4  Albania           Yield  hg/ha  2018  395766.0
# array(['Albania', 'Austria', 'Belarus', 'Belgium', 'Belgium-Luxembourg',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czechia',
#        'Czechoslovakia', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Malta', 'Netherlands',
#        'North Macedonia', 'Norway', 'Poland', 'Portugal',
#        'Republic of Moldova', 'Romania', 'Russian Federation', 'Serbia',
#        'Serbia and Montenegro', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Ukraine',
#        'United Kingdom of Great Britain and Northern Ireland', 'USSR',
#        'Yugoslav SFR'], dtype=object)

# %%
strawberries.to_csv('clean/strawberries_over_years_eu.csv')

# %% [markdown]
# #### **9. simple dataframe for apple production over the years in just 4 countries**

# %%
simpledf_applevalues = apples[['Brazil', 'Portugal', 'Spain', 'United Kingdom of Great Britain and Northern Ireland' ]]
simpledf_applevalues.columns = [['Br', 'Pt', 'Sp', 'UK']]
simpledf_applevalues.to_csv('clean/simpledf_applevalues.csv')

# %% [markdown]
# # Population
# **10. pop**

# %%
#import original dataset from csv downloaded from http://www.fao.org/faostat/en/#data/OA
pop = pd.read_csv('original/FAOSTAT_data_population.csv', encoding='latin1')
pop.head()
# Out:
#   ï»¿Domain Code             Domain  Area Code         Area  Element Code  \
# 0             OA  Annual population          2  Afghanistan           511
# 1             OA  Annual population          2  Afghanistan           512
# 2             OA  Annual population          2  Afghanistan           513
# 3             OA  Annual population          2  Afghanistan           551
# 4             OA  Annual population          2  Afghanistan           561
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1        Total Population - Male       3010  Population - Est. & Proj.
# 2      Total Population - Female       3010  Population - Est. & Proj.
# 3               Rural population       3010  Population - Est. & Proj.
# 4               Urban population       3010  Population - Est. & Proj.
#
#    Year Code  Year          Unit     Value Flag  \
# 0       1950  1950  1000 persons  7752.118    X
# 1       1950  1950  1000 persons  4099.243    X
# 2       1950  1950  1000 persons  3652.874    X
# 3       1950  1950  1000 persons  7286.991    X
# 4       1950  1950  1000 persons   465.127    X
#
#                  Flag Description  \
# 0  International reliable sources
# 1  International reliable sources
# 2  International reliable sources
# 3  International reliable sources
# 4  International reliable sources
#
#                                                 Note
# 0  UNDESA, Population Division â World Populati...
# 1  UNDESA, Population Division â World Populati...
# 2  UNDESA, Population Division â World Populati...
# 3                                                NaN
# 4  UNDESA, Population Division â World Urbaniza...

# %%
#remove redundant/unuseful columns for simple analysis, remove 'Y' from years
cols=[]

for col in pop.columns:
    if col.startswith(('Flag', 'Domain', 'Note')):
        pop.drop(columns=[col], inplace= True)
    elif col.endswith('Item'):
        pop.drop(columns=[col], inplace= True)
    elif col.endswith('Code'):
        pop.drop(columns=[col], inplace= True)
    else:
        cols.append(col)
        
pop.columns = cols
print(pop.shape)
pop.head()
# Out:
# (70585, 5)
#           Area                        Element  Year          Unit     Value
# 0  Afghanistan  Total Population - Both sexes  1950  1000 persons  7752.118
# 1  Afghanistan        Total Population - Male  1950  1000 persons  4099.243
# 2  Afghanistan      Total Population - Female  1950  1000 persons  3652.874
# 3  Afghanistan               Rural population  1950  1000 persons  7286.991
# 4  Afghanistan               Urban population  1950  1000 persons   465.127

# %%
pop.to_csv('clean/pop.csv')

# %% [markdown]
# # Crop residues

# %% [markdown]
# **11. all crop residues**

# %%
#import original dataset from csv downloaded from http://www.fao.org/faostat/en/#data/GA
df2 = pd.read_csv('original/Emissions_Agriculture_Crop_Residues_E_All_Data.csv', encoding='latin1')
df2.head()
# Out:
#    Area Code         Area  Item Code    Item  Element Code  \
# 0          2  Afghanistan         44  Barley         72392
# 1          2  Afghanistan         44  Barley         72292
# 2          2  Afghanistan         44  Barley         72342
# 3          2  Afghanistan         44  Barley         72352
# 4          2  Afghanistan         44  Barley         72362
#
#                                            Element             Unit  \
# 0                         Residues (Crop residues)  kg of nutrients
# 1  Implied emission factor for N2O (Crop residues)    kg N2O-N/kg N
# 2           Direct emissions (N2O) (Crop residues)        gigagrams
# 3         Direct emissions (CO2eq) (Crop residues)        gigagrams
# 4         Indirect emissions (N2O) (Crop residues)        gigagrams
#
#           Y1961 Y1961F         Y1962  ...         Y2016  Y2016F         Y2017  \
# 0  5.925706e+06     Fc  5.925706e+06  ...  4.402174e+06      Fc  1.380965e+06
# 1  1.230000e-02     Fc  1.230000e-02  ...  1.230000e-02      Fc  1.230000e-02
# 2  9.310000e-02     Fc  9.310000e-02  ...  6.920000e-02      Fc  2.170000e-02
# 3  2.886670e+01     Fc  2.886670e+01  ...  2.144490e+01      Fc  6.727300e+00
# 4  2.100000e-02     Fc  2.100000e-02  ...  1.560000e-02      Fc  4.900000e-03
#
#    Y2017F         Y2018  Y2018F         Y2030  Y2030F         Y2050  Y2050F
# 0      Fc  1.062870e+06      Fc  8.779633e+06      Fc  1.406071e+07      Fc
# 1      Fc  1.230000e-02      Fc  1.220000e-02      Fc  1.230000e-02      Fc
# 2      Fc  1.670000e-02      Fc  1.380000e-01      Fc  2.210000e-01      Fc
# 3      Fc  5.177700e+00      Fc  4.276940e+01      Fc  6.849580e+01      Fc
# 4      Fc  3.800000e-03      Fc  3.100000e-02      Fc  4.970000e-02      Fc
#
# [5 rows x 127 columns]

# %%
#remove redundant/unuseful columns for simple analysis, remove 'Y' from years
cols=[]

for col in df2:
    if col.endswith('F'):
        df2.drop(columns=[col], inplace= True)
    elif col.endswith('Code'):
        df2.drop(columns=[col], inplace= True)
    elif col.startswith('Y'):
        cols.append(int(col.replace('Y','')))
    else:
        cols.append(col)
        
df2.columns = cols
df2t = df2.drop(columns=['Area', 'Item', 'Element', 'Unit'])
df2['average_1961-2019'] = df2t.mean(axis=1)
df2['std_1961-2019'] = df2t.std(axis=1)
df2.to_csv('clean/all_data_crop_residues.csv')
df2.head()
# Out:
#           Area    Item                                          Element  \
# 0  Afghanistan  Barley                         Residues (Crop residues)
# 1  Afghanistan  Barley  Implied emission factor for N2O (Crop residues)
# 2  Afghanistan  Barley           Direct emissions (N2O) (Crop residues)
# 3  Afghanistan  Barley         Direct emissions (CO2eq) (Crop residues)
# 4  Afghanistan  Barley         Indirect emissions (N2O) (Crop residues)
#
#               Unit          1961          1962          1963          1964  \
# 0  kg of nutrients  5.925706e+06  5.925706e+06  5.925706e+06  5.946927e+06
# 1    kg N2O-N/kg N  1.230000e-02  1.230000e-02  1.230000e-02  1.230000e-02
# 2        gigagrams  9.310000e-02  9.310000e-02  9.310000e-02  9.350000e-02
# 3        gigagrams  2.886670e+01  2.886670e+01  2.886670e+01  2.897000e+01
# 4        gigagrams  2.100000e-02  2.100000e-02  2.100000e-02  2.100000e-02
#
#            1965          1966  ...          2013          2014          2015  \
# 0  5.946927e+06  5.893875e+06  ...  6.974770e+06  7.401796e+06  5.818908e+06
# 1  1.230000e-02  1.230000e-02  ...  1.230000e-02  1.230000e-02  1.230000e-02
# 2  9.350000e-02  9.260000e-02  ...  1.096000e-01  1.163000e-01  9.140000e-02
# 3  2.897000e+01  2.871160e+01  ...  3.397710e+01  3.605730e+01  2.834640e+01
# 4  2.100000e-02  2.080000e-02  ...  2.470000e-02  2.620000e-02  2.060000e-02
#
#            2016          2017          2018          2030          2050  \
# 0  4.402174e+06  1.380965e+06  1.062870e+06  8.779633e+06  1.406071e+07
# 1  1.230000e-02  1.230000e-02  1.230000e-02  1.220000e-02  1.230000e-02
# 2  6.920000e-02  2.170000e-02  1.670000e-02  1.380000e-01  2.210000e-01
# 3  2.144490e+01  6.727300e+00  5.177700e+00  4.276940e+01  6.849580e+01
# 4  1.560000e-02  4.900000e-03  3.800000e-03  3.100000e-02  4.970000e-02
#
#    average_1961-2019  std_1961-2019
# 0       4.892098e+06   1.890840e+06
# 1       1.229000e-02   3.025317e-05
# 2       7.687167e-02   2.971819e-02
# 3       2.383151e+01   9.211096e+00
# 4       1.730167e-02   6.681533e-03
#
# [5 rows x 66 columns]

# %% [markdown]
# #### **12 . crop residues in europe**

# %%
cropres_eu = pd.DataFrame (df2)

for i, row in cropres_eu.iterrows():
    try:
        if cropres_eu.iloc[i,0] not in europecountries:
            cropres_eu.drop(i, inplace=True)
    except:
        continue

print(cropres_eu.shape)
cropres_eu.to_csv('clean/cropresidues_europe.csv')
cropres_eu.head()
# Out:
# (9144, 66)
#            Area         Item                                     Element  \
# 28  Afghanistan     Potatoes    Indirect emissions (N2O) (Crop residues)
# 29  Afghanistan     Potatoes  Indirect emissions (CO2eq) (Crop residues)
# 30  Afghanistan     Potatoes             Emissions (N2O) (Crop residues)
# 31  Afghanistan     Potatoes           Emissions (CO2eq) (Crop residues)
# 32  Afghanistan  Rice, paddy                    Residues (Crop residues)
#
#                Unit          1961          1962          1963          1964  \
# 28        gigagrams  1.600000e-03  1.500000e-03  1.600000e-03  1.600000e-03
# 29        gigagrams  4.931000e-01  4.766000e-01  4.843000e-01  4.920000e-01
# 30        gigagrams  8.700000e-03  8.400000e-03  8.500000e-03  8.600000e-03
# 31        gigagrams  2.684900e+00  2.594700e+00  2.636800e+00  2.678900e+00
# 32  kg of nutrients  6.481699e+06  6.481699e+06  6.481699e+06  7.145110e+06
#
#             1965          1966  ...          2013          2014          2015  \
# 28  1.600000e-03  1.600000e-03  ...  2.800000e-03  3.100000e-03  3.000000e-03
# 29  4.954000e-01  4.998000e-01  ...  8.697000e-01  9.587000e-01  9.448000e-01
# 30  8.700000e-03  8.800000e-03  ...  1.530000e-02  1.680000e-02  1.660000e-02
# 31  2.697000e+00  2.721000e+00  ...  4.735200e+00  5.219400e+00  5.144000e+00
# 32  7.145110e+06  6.850311e+06  ...  7.881552e+06  8.360951e+06  6.307757e+06
#
#             2016          2017          2018          2030          2050  \
# 28  4.200000e-03  4.200000e-03  4.600000e-03  5.300000e-03  9.400000e-03
# 29  1.304600e+00  1.315300e+00  1.435200e+00  1.635700e+00  2.902300e+00
# 30  2.290000e-02  2.310000e-02  2.520000e-02  2.870000e-02  5.100000e-02
# 31  7.102900e+00  7.161200e+00  7.813700e+00  8.905600e+00  1.580120e+01
# 32  5.034382e+06  4.711483e+06  4.972493e+06  1.061053e+07  1.454365e+07
#
#     average_1961-2019  std_1961-2019
# 28       2.360000e-03   1.189103e-03
# 29       7.313050e-01   3.682238e-01
# 30       1.285000e-02   6.465882e-03
# 31       3.981562e+00   2.004742e+00
# 32       6.773198e+06   1.578952e+06
#
# [5 rows x 66 columns]

# %% [markdown]
# # Food waste
# **13. most simple dataframe**

# %%
#import original dataset from csv downloaded from http://www.fao.org/sustainable-development-goals/indicators/1231/en/
foodwaste = pd.read_excel('original/Foodwaste_March_2020.xlsx', usecols=['GeoAreaName', 'Value'])
foodwaste.dropna(subset=['Value'], inplace=True)
foodwaste = foodwaste.reset_index(drop=True)
foodwaste.head()
# Out:
#                                          GeoAreaName  Value
# 0            Northern America (M49) and Europe (M49)   15.7
# 1                           Sub-Saharan Africa (M49)   14.0
# 2          Latin America and the Caribbean (MDG=M49)   11.6
# 3     Central Asia (M49) and Southern Asia (MDG=M49)   20.7
# 4  Eastern Asia (M49) and South-eastern Asia (MDG...    7.8

# %%
foodwaste.shape
# Out:
# (9, 2)

# %%
foodwaste.to_csv('clean/foodwaste.csv')

# %% [markdown]
# ## food loss
# **14. all data food loss**

# %%
#import original dataset from csv downloaded from http://www.fao.org/platform-food-loss-waste/flw-data/en/
#looking at missing data I focus in this columns for exercises
alldatafoodloss = pd.read_csv('original/Data_all_food_loss.csv', encoding='latin1', usecols=['country', 
                            'crop', 'timepointyears','percentage_loss_of_quantity', 'activity',
                            'fsc_location1'])
print(alldatafoodloss.shape)
display(alldatafoodloss.tail())
# convert percent loss values in floats when possible (now str), when not possible set to missing value
for i, item in alldatafoodloss.percentage_loss_of_quantity.iteritems():
    try:
        alldatafoodloss.loc[i,'percentage_loss_of_quantity'] = float(item)
    except:
        alldatafoodloss.loc[i,'percentage_loss_of_quantity'] = np.nan
display(alldatafoodloss.info())
# Out:
# (9492, 6)
#      country          crop  timepointyears percentage_loss_of_quantity  \
# 9487  Zambia  Maize (corn)            2007                         3.3
# 9488  Zambia  Maize (corn)            2007                         3.8
# 9489  Zambia  Maize (corn)            2007                         5.1
# 9490  Zambia  Maize (corn)            2007                         2.2
# 9491  Zambia  Maize (corn)            2007                         3.3
#
#                      activity fsc_location1
# 9487                      NaN          Farm
# 9488          Platform drying          Farm
# 9489  Harvesting/field drying       Harvest
# 9490        Transport to farm          Farm
# 9491             Farm storage       Storage
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9492 entries, 0 to 9491
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      9492 non-null   object
#  1   crop                         9492 non-null   object
#  2   timepointyears               9492 non-null   int64
#  3   percentage_loss_of_quantity  7972 non-null   object
#  4   activity                     6647 non-null   object
#  5   fsc_location1                9384 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 445.1+ KB
# None

# %%
alldatafoodloss.to_csv('clean/alldatafoodloss.csv')

# %% [markdown]
# **15. data food loss in europe**

# %%
eufoodloss = alldatafoodloss[alldatafoodloss.country.isin(europecountries)].reset_index(drop=True)
eufoodloss = eufoodloss[eufoodloss.fsc_location1 != 'SWS_Total'] #SWS the FAO Statistical Working System
eufoodloss.tail()
# Out:
#          country      crop  timepointyears percentage_loss_of_quantity  \
# 362  Switzerland  Potatoes            2015                       0.008
# 363  Switzerland  Potatoes            2015                       0.045
# 364  Switzerland  Potatoes            2015                       0.003
# 365  Switzerland  Potatoes            2015                       0.008
# 366  Switzerland  Potatoes            2015                       0.045
#
#     activity fsc_location1
# 362      NaN    Processing
# 363      NaN          Farm
# 364      NaN     Wholesale
# 365      NaN    Processing
# 366      NaN          Farm

# %%
eufoodloss.to_csv('clean/eufoodloss.csv')
