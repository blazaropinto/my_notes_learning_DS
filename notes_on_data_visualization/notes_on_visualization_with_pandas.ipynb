# %% [markdown]
# * pandas is a foundational library for analyzing data that also supports basic plotting capability

# %%
import pandas as pd

# %%
# use matplotlib to add features
import matplotlib.pyplot as plt

# Set default size for figures
plt.rcParams['figure.figsize'] = (16, 5)

# %%
# load data
simpapp = pd.read_csv('../datasets/clean/simpledf_applevalues.csv', index_col=0)
simpapp.head()
# Out:
#            Br       Pt        Sp        UK
# 1961  19962.0  70000.0  385500.0  339000.0
# 1962  22600.0  58000.0  274500.0  583000.0
# 1963  23241.0  92000.0  480700.0  545000.0
# 1964  21158.0  85000.0  321600.0  653000.0
# 1965  40386.0  96000.0  446800.0  529000.0

# %% [markdown]
# ### histogram

# %%
simpapp['Br'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### barplots

# %%
simpapp['Br'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
simpapp['Br'].plot.barh(figsize = (5,16))
# Out:
# <AxesSubplot:>
