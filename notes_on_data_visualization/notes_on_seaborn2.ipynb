# %% [markdown]
# ## types of graphs

# %%
# Imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set default size for figures
plt.rcParams['figure.figsize'] = (16, 5)

# %%
# load data
simp_app = pd.read_csv('../datasets/clean/simpledf_applevalues.csv', index_col=0)
simp_app.head()
# Out:
#            Br       Pt        Sp        UK
# 1961  19962.0  70000.0  385500.0  339000.0
# 1962  22600.0  58000.0  274500.0  583000.0
# 1963  23241.0  92000.0  480700.0  545000.0
# 1964  21158.0  85000.0  321600.0  653000.0
# 1965  40386.0  96000.0  446800.0  529000.0

# %% [markdown]
# #### distplot
# * similar to an histogram
# * by default, generates a Gaussian Kernel Density Estimate (KDE)
# * in order to plot a simple histogram, disable the `kde` and specify the number of `bins` to use
# * alternatively, you can combine a `rug` plot and a kde curve while diactivating the histogram to view the distribution of data
# * the plot can be further customized by passing arguments to the underlying function (dictionary to the parameter `kde_kws`, for instance)

# %%
# '_' is the convention in python for variables not to be used again
_ = sns.distplot(simp_app['Br'])
plt.show()
# Out:
# C:\Users\bea\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
_ = sns.distplot(simp_app['Br'], kde=False, bins=14)
plt.show()
# Out:
# C:\Users\bea\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
_ = sns.distplot(simp_app['Br'], hist=False, rug=True, kde_kws={'shade':True})
plt.show()
# Out:
# C:\Users\bea\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bea\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### regplot
# * usage is similar to distplot
# * generates a sca?er plot with a regression line
# * The `data` and `x` and `y` variables must be always defined

# %%
sns.regplot(x='Br', y='Pt', data=simp_app)
plt.show()

# %%
sns.lmplot(x='Br', y='Pt', data=simp_app) #lmplot allows faceting (hue-organize by colors, col-organize data by columns...)
plt.show()
