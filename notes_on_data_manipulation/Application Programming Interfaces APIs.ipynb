# %% [markdown]
# An API is a set of protocols and routines for building and interacting with software applications, a bunch of code that allows two software programs to communicate with each other

# %% [markdown]
# A standard form for transferring data through APIs is the JSON file format
#
# JSON is an acronym that is short for JavaScript Object Notation. It is a file format that arose out of a growing need for real-time server-to-browser communication that wouldn't necessarily rely on Flash or Java.
#
# The json package is part of the standard library.
#
# * to load a JSONs string into a Python object (a dict)
# ```
# import json
# with open('jfile.json', 'r') as json_file:
#     json_data = json.load(json_file)
# ```
#
# * to convert a Python object into a string.
#
# ```
# json.dumps()
# ```

# %% [markdown]
# To connect to an API in python use requests and the pertinent url
#
#
# Status codes are returned with every request that is made to a web server:  all of the status codes that begin with a ‘4’ indicate some sort of error.

# %% [markdown]
# ## open notify API

# %%
import requests

response = requests.get("http://api.open-notify.org/this-wont-work")
print(response.status_code)
# Out:
# 404

# %% [markdown]
# The following API returns the current number of people in space.
# When known it also returns the names and spacecraft those people are on. This API takes no inputs.

# %%
response = requests.get("http://api.open-notify.org/astros.json")
print(response.status_code)
# Out:
# 200

# %%
astro_json = response.json()
print(astro_json)
# Out:
# {'message': 'success', 'number': 7, 'people': [{'craft': 'ISS', 'name': 'Sergey Ryzhikov'}, {'craft': 'ISS', 'name': 'Kate Rubins'}, {'craft': 'ISS', 'name': 'Sergey Kud-Sverchkov'}, {'craft': 'ISS', 'name': 'Mike Hopkins'}, {'craft': 'ISS', 'name': 'Victor Glover'}, {'craft': 'ISS', 'name': 'Shannon Walker'}, {'craft': 'ISS', 'name': 'Soichi Noguchi'}]}

# %%
import json

print(json.dumps(astro_json, sort_keys=True, indent=4)) #that only works when using print
# Out:
# {
#     "message": "success",
#     "number": 7,
#     "people": [
#         {
#             "craft": "ISS",
#             "name": "Sergey Ryzhikov"
#         },
#         {
#             "craft": "ISS",
#             "name": "Kate Rubins"
#         },
#         {
#             "craft": "ISS",
#             "name": "Sergey Kud-Sverchkov"
#         },
#         {
#             "craft": "ISS",
#             "name": "Mike Hopkins"
#         },
#         {
#             "craft": "ISS",
#             "name": "Victor Glover"
#         },
#         {
#             "craft": "ISS",
#             "name": "Shannon Walker"
#         },
#         {
#             "craft": "ISS",
#             "name": "Soichi Noguchi"
#         }
#     ]
# }

# %% [markdown]
# ### query parameters for the QPI request
#
# * Make a dictionary with the parameters to pass them into requests.get
# * add them to the URL (after ?)

# %%
# to get the next times that the international space station will pass over a given location on the earth (Edinburgh Castle)
parameters = {
    "lat": 55.95,
    "lon": -3.19
}

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "message": "success",
#     "request": {
#         "altitude": 100,
#         "datetime": 1617646577,
#         "latitude": 55.95,
#         "longitude": -3.19,
#         "passes": 5
#     },
#     "response": [
#         {
#             "duration": 559,
#             "risetime": 1617648048
#         },
#         {
#             "duration": 190,
#             "risetime": 1617653965
#         },
#         {
#             "duration": 316,
#             "risetime": 1617708671
#         },
#         {
#             "duration": 580,
#             "risetime": 1617714279
#         },
#         {
#             "duration": 637,
#             "risetime": 1617720022
#         }
#     ]
# }

# %%
from datetime import datetime

resp = response.json()['response']

for d in resp:
    time = datetime.fromtimestamp(d['risetime'])
    print(time)
# Out:
# 2021-04-05 19:40:48
# 2021-04-05 21:19:25
# 2021-04-06 12:31:11
# 2021-04-06 14:04:39
# 2021-04-06 15:40:22

# %% [markdown]
# ## MetaWeather API

# %%
url = 'https://www.metaweather.com/api/location/search/?query=edinburgh'
response_ed = requests.get(url)
response_ed.status_code
# Out:
# 200

# %%
print(json.dumps(response_ed.json(), sort_keys=True, indent=4))
# Out:
# [
#     {
#         "latt_long": "55.954151,-3.202770",
#         "location_type": "City",
#         "title": "Edinburgh",
#         "woeid": 19344
#     }
# ]

# %%
type(response_ed.json()[0])
# Out:
# dict

# %%
from datetime import date

current_date = date.today()

url = 'https://www.metaweather.com/api/location/'+ str(response_ed.json()[0]['woeid']) + current_date.strftime(format='/%Y/%m/%d/')
resp = requests.get(url)
resp.status_code
# Out:
# 200

# %%
print(json.dumps(resp.json(), sort_keys=True, indent=4))
# Out:
# [
#     {
#         "air_pressure": 1020.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-05T15:58:42.597686Z",
#         "humidity": 47,
#         "id": 6580181503311872,
#         "max_temp": 6.235,
#         "min_temp": -1.455,
#         "predictability": 75,
#         "the_temp": 5.105,
#         "visibility": 16.4871525292293,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.66194481070727,
#         "wind_direction_compass": "NW",
#         "wind_speed": 11.606363430562846
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-05T12:58:45.891560Z",
#         "humidity": 46,
#         "id": 5763809923825664,
#         "max_temp": 5.8100000000000005,
#         "min_temp": -1.4449999999999998,
#         "predictability": 75,
#         "the_temp": 4.65,
#         "visibility": 17.607174103237096,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.9935702385353,
#         "wind_direction_compass": "NW",
#         "wind_speed": 12.891769612232563
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-05T09:58:43.913263Z",
#         "humidity": 44,
#         "id": 6016445705093120,
#         "max_temp": 5.8,
#         "min_temp": -1.325,
#         "predictability": 75,
#         "the_temp": 4.585,
#         "visibility": 18.55445448580291,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.9935702385353,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.87557757889923
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-05T06:58:43.356552Z",
#         "humidity": 45,
#         "id": 6236638209376256,
#         "max_temp": 5.79,
#         "min_temp": -1.42,
#         "predictability": 75,
#         "the_temp": 4.705,
#         "visibility": 17.739526167183648,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.66194481070727,
#         "wind_direction_compass": "NW",
#         "wind_speed": 14.17217777557199
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-05T03:58:43.890642Z",
#         "humidity": 45,
#         "id": 6543940569268224,
#         "max_temp": 5.745,
#         "min_temp": -1.505,
#         "predictability": 75,
#         "the_temp": 4.605,
#         "visibility": 19.143514376043903,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.66194481070727,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.858833308905327
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-05T00:58:43.863382Z",
#         "humidity": 53,
#         "id": 6654236671606784,
#         "max_temp": 5.705,
#         "min_temp": -1.7,
#         "predictability": 77,
#         "the_temp": 7.025,
#         "visibility": 11.489774715660541,
#         "weather_state_abbr": "hr",
#         "weather_state_name": "Heavy Rain",
#         "wind_direction": 301.15471054684565,
#         "wind_direction_compass": "WNW",
#         "wind_speed": 13.86628953250351
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T21:58:47.322662Z",
#         "humidity": 45,
#         "id": 5227000718426112,
#         "max_temp": 5.705,
#         "min_temp": -1.7,
#         "predictability": 75,
#         "the_temp": 4.485,
#         "visibility": 17.3726064781675,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.66194481070727,
#         "wind_direction_compass": "NW",
#         "wind_speed": 14.201829032503516
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T18:58:47.412581Z",
#         "humidity": 45,
#         "id": 6625991825817600,
#         "max_temp": 5.785,
#         "min_temp": -1.68,
#         "predictability": 75,
#         "the_temp": 4.609999999999999,
#         "visibility": 18.725642249264297,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 320.66717930710007,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.599158463156499
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T15:58:47.189868Z",
#         "humidity": 45,
#         "id": 6101356940099584,
#         "max_temp": 5.785,
#         "min_temp": -1.68,
#         "predictability": 75,
#         "the_temp": 4.665,
#         "visibility": 18.11203819692993,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 320.66717930710007,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.912328663156499
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T12:58:46.420914Z",
#         "humidity": 45,
#         "id": 6331881525084160,
#         "max_temp": 5.615,
#         "min_temp": -1.6549999999999998,
#         "predictability": 75,
#         "the_temp": 4.6850000000000005,
#         "visibility": 18.76012835043347,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.624013415713565
#     },
#     {
#         "air_pressure": 1021.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T09:58:47.522181Z",
#         "humidity": 44,
#         "id": 5316376236392448,
#         "max_temp": 5.57,
#         "min_temp": -1.685,
#         "predictability": 75,
#         "the_temp": 4.605,
#         "visibility": 17.178117294997215,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.933931849046898
#     },
#     {
#         "air_pressure": 1021.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T06:58:46.232787Z",
#         "humidity": 45,
#         "id": 5949251478618112,
#         "max_temp": 5.455,
#         "min_temp": -1.7799999999999998,
#         "predictability": 75,
#         "the_temp": 4.46,
#         "visibility": 17.178117294997215,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 320.66717930710007,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.898720814820116
#     },
#     {
#         "air_pressure": 1020.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T03:58:47.403465Z",
#         "humidity": 45,
#         "id": 4882339323707392,
#         "max_temp": 5.555,
#         "min_temp": -1.77,
#         "predictability": 75,
#         "the_temp": 4.395,
#         "visibility": 18.67779666746202,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.00152669071974,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.466166114820117
#     },
#     {
#         "air_pressure": 1019.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-04T00:58:46.565114Z",
#         "humidity": 53,
#         "id": 5353169476386816,
#         "max_temp": 5.52,
#         "min_temp": -1.685,
#         "predictability": 75,
#         "the_temp": 6.9,
#         "visibility": 12.675661636045493,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 301.2013313980823,
#         "wind_direction_compass": "WNW",
#         "wind_speed": 14.113632883674008
#     },
#     {
#         "air_pressure": 1020.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T21:58:49.044009Z",
#         "humidity": 45,
#         "id": 5339876418387968,
#         "max_temp": 5.52,
#         "min_temp": -1.685,
#         "predictability": 75,
#         "the_temp": 4.43,
#         "visibility": 15.723798019565736,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.6673835118722,
#         "wind_direction_compass": "NW",
#         "wind_speed": 13.97941708367401
#     },
#     {
#         "air_pressure": 1020.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T18:58:49.300446Z",
#         "humidity": 46,
#         "id": 6210442230759424,
#         "max_temp": 5.0600000000000005,
#         "min_temp": -1.635,
#         "predictability": 75,
#         "the_temp": 4.550000000000001,
#         "visibility": 15.761390976696095,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.3326164881278,
#         "wind_direction_compass": "NW",
#         "wind_speed": 14.279777379546118
#     },
#     {
#         "air_pressure": 1019.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T15:58:50.403674Z",
#         "humidity": 46,
#         "id": 6458462801231872,
#         "max_temp": 5.0600000000000005,
#         "min_temp": -1.635,
#         "predictability": 75,
#         "the_temp": 4.545,
#         "visibility": 17.384101845223892,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.3326164881278,
#         "wind_direction_compass": "NW",
#         "wind_speed": 14.085910112879452
#     },
#     {
#         "air_pressure": 1019.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T12:58:49.458340Z",
#         "humidity": 45,
#         "id": 4742537467133952,
#         "max_temp": 5.140000000000001,
#         "min_temp": -1.625,
#         "predictability": 75,
#         "the_temp": 4.505,
#         "visibility": 16.484667044460352,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 320.00101701768256,
#         "wind_direction_compass": "NW",
#         "wind_speed": 14.103308002897746
#     },
#     {
#         "air_pressure": 1018.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T09:58:50.143642Z",
#         "humidity": 44,
#         "id": 4702808348557312,
#         "max_temp": 5.445,
#         "min_temp": -1.575,
#         "predictability": 75,
#         "the_temp": 4.525,
#         "visibility": 13.330586872663643,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 320.3349908640192,
#         "wind_direction_compass": "NW",
#         "wind_speed": 15.051669169564411
#     },
#     {
#         "air_pressure": 1017.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T06:58:49.089453Z",
#         "humidity": 45,
#         "id": 5792399272968192,
#         "max_temp": 5.385,
#         "min_temp": -1.775,
#         "predictability": 75,
#         "the_temp": 4.58,
#         "visibility": 13.407326214904954,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 320.6683322396841,
#         "wind_direction_compass": "NW",
#         "wind_speed": 15.455974230562846
#     },
#     {
#         "air_pressure": 1017.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T03:58:49.198982Z",
#         "humidity": 44,
#         "id": 5601626288029696,
#         "max_temp": 5.195,
#         "min_temp": -1.815,
#         "predictability": 75,
#         "the_temp": 4.62,
#         "visibility": 15.936306967310903,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 320.33417736024785,
#         "wind_direction_compass": "NW",
#         "wind_speed": 15.303070997229513
#     },
#     {
#         "air_pressure": 1016.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-03T00:58:50.892889Z",
#         "humidity": 54,
#         "id": 4730063103721472,
#         "max_temp": 5.210000000000001,
#         "min_temp": -1.645,
#         "predictability": 75,
#         "the_temp": 6.875,
#         "visibility": 13.566086554521593,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 300.4474864360062,
#         "wind_direction_compass": "WNW",
#         "wind_speed": 15.207794815159467
#     },
#     {
#         "air_pressure": 1014.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T21:58:52.998261Z",
#         "humidity": 47,
#         "id": 5553569932509184,
#         "max_temp": 5.210000000000001,
#         "min_temp": -1.645,
#         "predictability": 75,
#         "the_temp": 4.655,
#         "visibility": 12.218332438558816,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 321.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 16.21441331515947
#     },
#     {
#         "air_pressure": 1014.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T18:58:53.093499Z",
#         "humidity": 48,
#         "id": 6284645088886784,
#         "max_temp": 4.375,
#         "min_temp": -1.345,
#         "predictability": 75,
#         "the_temp": 4.275,
#         "visibility": 12.330179253161536,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 322.3248865875779,
#         "wind_direction_compass": "NW",
#         "wind_speed": 16.19078577760545
#     },
#     {
#         "air_pressure": 1014.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T15:58:52.505540Z",
#         "humidity": 48,
#         "id": 4966430723276800,
#         "max_temp": 4.375,
#         "min_temp": -1.345,
#         "predictability": 75,
#         "the_temp": 4.3,
#         "visibility": 12.725060645828362,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 322.3248865875779,
#         "wind_direction_compass": "NW",
#         "wind_speed": 16.041657110938782
#     },
#     {
#         "air_pressure": 1012.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T12:58:52.530322Z",
#         "humidity": 48,
#         "id": 6427239060078592,
#         "max_temp": 4.03,
#         "min_temp": -1.4,
#         "predictability": 75,
#         "the_temp": 4.15,
#         "visibility": 11.834014356160026,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 322.3248865875779,
#         "wind_direction_compass": "NW",
#         "wind_speed": 16.239252856441052
#     },
#     {
#         "air_pressure": 1012.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T09:58:52.604422Z",
#         "humidity": 48,
#         "id": 4859840271745024,
#         "max_temp": 4.775,
#         "min_temp": -1.4300000000000002,
#         "predictability": 75,
#         "the_temp": 4.04,
#         "visibility": 11.5972719319176,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 323.33210433550124,
#         "wind_direction_compass": "NW",
#         "wind_speed": 16.451540589774385
#     },
#     {
#         "air_pressure": 1011.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T06:58:52.605050Z",
#         "humidity": 48,
#         "id": 6722790490112000,
#         "max_temp": 4.965,
#         "min_temp": -1.42,
#         "predictability": 75,
#         "the_temp": 4.23,
#         "visibility": 11.5972719319176,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 324.65731657806555,
#         "wind_direction_compass": "NW",
#         "wind_speed": 16.381118521320822
#     },
#     {
#         "air_pressure": 1012.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T03:58:52.955815Z",
#         "humidity": 48,
#         "id": 4522054784122880,
#         "max_temp": 4.95,
#         "min_temp": -1.415,
#         "predictability": 80,
#         "the_temp": 4.335,
#         "visibility": 14.430103197327606,
#         "weather_state_abbr": "t",
#         "weather_state_name": "Thunder",
#         "wind_direction": 332.1762275402801,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 15.809957954654152
#     },
#     {
#         "air_pressure": 1012.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-02T00:58:52.790546Z",
#         "humidity": 55,
#         "id": 4779030730506240,
#         "max_temp": 5.195,
#         "min_temp": -1.385,
#         "predictability": 82,
#         "the_temp": 6.57,
#         "visibility": 12.425559731169967,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 303.79836297006915,
#         "wind_direction_compass": "NW",
#         "wind_speed": 15.108224705424321
#     },
#     {
#         "air_pressure": 1010.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T21:58:55.009267Z",
#         "humidity": 48,
#         "id": 4639152772481024,
#         "max_temp": 5.195,
#         "min_temp": -1.385,
#         "predictability": 82,
#         "the_temp": 4.445,
#         "visibility": 12.197827189214983,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 331.5065014571948,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 16.02536600542432
#     },
#     {
#         "air_pressure": 1010.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T18:58:55.222887Z",
#         "humidity": 50,
#         "id": 6204072290942976,
#         "max_temp": 4.855,
#         "min_temp": -1.335,
#         "predictability": 75,
#         "the_temp": 4.1450000000000005,
#         "visibility": 12.301906863914738,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 332.84926866798514,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 15.90183913567698
#     },
#     {
#         "air_pressure": 1010.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T15:58:54.930517Z",
#         "humidity": 49,
#         "id": 6143545162334208,
#         "max_temp": 4.855,
#         "min_temp": -1.335,
#         "predictability": 75,
#         "the_temp": 4.175,
#         "visibility": 14.194603515469655,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 332.84926866798514,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 15.245673002343645
#     },
#     {
#         "air_pressure": 1007.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T12:58:56.817553Z",
#         "humidity": 49,
#         "id": 4786852469932032,
#         "max_temp": 4.79,
#         "min_temp": -0.635,
#         "predictability": 75,
#         "the_temp": 4.32,
#         "visibility": 13.062154517617117,
#         "weather_state_abbr": "lr",
#         "weather_state_name": "Light Rain",
#         "wind_direction": 334.85118428623093,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 15.404329129915956
#     },
#     {
#         "air_pressure": 1007.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T09:58:56.402642Z",
#         "humidity": 50,
#         "id": 4566163829817344,
#         "max_temp": 4.04,
#         "min_temp": -0.62,
#         "predictability": 82,
#         "the_temp": 4.22,
#         "visibility": 11.558125546806648,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 335.1809755828458,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 15.592853429915957
#     },
#     {
#         "air_pressure": 1007.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T06:58:56.000057Z",
#         "humidity": 50,
#         "id": 5612071648493568,
#         "max_temp": 3.7800000000000002,
#         "min_temp": -1.545,
#         "predictability": 82,
#         "the_temp": 3.975,
#         "visibility": 11.388180525729737,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 330.83643918669793,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 15.706771796428855
#     },
#     {
#         "air_pressure": 1008.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T03:58:55.757537Z",
#         "humidity": 54,
#         "id": 4705252050731008,
#         "max_temp": 4.47,
#         "min_temp": -1.015,
#         "predictability": 77,
#         "the_temp": 3.9,
#         "visibility": 12.782537481110316,
#         "weather_state_abbr": "hr",
#         "weather_state_name": "Heavy Rain",
#         "wind_direction": 333.83270716458844,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 14.398677596428856
#     },
#     {
#         "air_pressure": 1007.5,
#         "applicable_date": "2021-04-05",
#         "created": "2021-04-01T00:58:55.097420Z",
#         "humidity": 62,
#         "id": 5519300354899968,
#         "max_temp": 4.88,
#         "min_temp": -1.135,
#         "predictability": 80,
#         "the_temp": 6.455,
#         "visibility": 11.202390539250775,
#         "weather_state_abbr": "t",
#         "weather_state_name": "Thunder",
#         "wind_direction": 307.7598266870682,
#         "wind_direction_compass": "NW",
#         "wind_speed": 14.582603091807842
#     },
#     {
#         "air_pressure": 1007.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T21:58:58.535338Z",
#         "humidity": 57,
#         "id": 4799446186459136,
#         "max_temp": 4.88,
#         "min_temp": -1.135,
#         "predictability": 82,
#         "the_temp": 4.14,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 333.5,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 10.789916487711764
#     },
#     {
#         "air_pressure": 1009.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T18:58:58.226229Z",
#         "humidity": 64,
#         "id": 4879916156846080,
#         "max_temp": 4.515000000000001,
#         "min_temp": 0.17000000000000004,
#         "predictability": 82,
#         "the_temp": 3.8,
#         "visibility": 9.763605543625228,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 339.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 9.948017179670723
#     },
#     {
#         "air_pressure": 1009.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T15:58:58.013937Z",
#         "humidity": 64,
#         "id": 4804208097230848,
#         "max_temp": 4.515000000000001,
#         "min_temp": 0.17000000000000004,
#         "predictability": 82,
#         "the_temp": 3.8,
#         "visibility": 9.763605543625228,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 339.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 9.948017179670723
#     },
#     {
#         "air_pressure": 1005.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T12:58:58.117669Z",
#         "humidity": 66,
#         "id": 5020811887902720,
#         "max_temp": 4.785,
#         "min_temp": 0.04500000000000004,
#         "predictability": 82,
#         "the_temp": 4.01,
#         "visibility": 9.763605543625228,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 342.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 9.519271057026963
#     },
#     {
#         "air_pressure": 1005.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T09:58:59.152742Z",
#         "humidity": 53,
#         "id": 5199719086161920,
#         "max_temp": 5.23,
#         "min_temp": -0.5549999999999999,
#         "predictability": 77,
#         "the_temp": 4.01,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "hr",
#         "weather_state_name": "Heavy Rain",
#         "wind_direction": 321.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 9.964271057026963
#     },
#     {
#         "air_pressure": 1005.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T06:58:58.608370Z",
#         "humidity": 50,
#         "id": 4905805884162048,
#         "max_temp": 5.775,
#         "min_temp": -0.18,
#         "predictability": 77,
#         "the_temp": 5.43,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "hr",
#         "weather_state_name": "Heavy Rain",
#         "wind_direction": 316.5,
#         "wind_direction_compass": "NW",
#         "wind_speed": 10.52661198600175
#     },
#     {
#         "air_pressure": 1005.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T03:59:00.214965Z",
#         "humidity": 50,
#         "id": 6003196267855872,
#         "max_temp": 5.88,
#         "min_temp": -0.205,
#         "predictability": 90,
#         "the_temp": 5.43,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 317.5,
#         "wind_direction_compass": "NW",
#         "wind_speed": 10.471611986001749
#     },
#     {
#         "air_pressure": 1009.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-31T00:58:59.201733Z",
#         "humidity": 51,
#         "id": 5025135678455808,
#         "max_temp": 5.43,
#         "min_temp": -0.31999999999999995,
#         "predictability": 90,
#         "the_temp": 4.53,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 322.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 10.021117871629682
#     },
#     {
#         "air_pressure": 1009.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T21:59:01.500678Z",
#         "humidity": 51,
#         "id": 6535221114568704,
#         "max_temp": 5.43,
#         "min_temp": -0.31999999999999995,
#         "predictability": 90,
#         "the_temp": 4.53,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 322.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 10.021117871629682
#     },
#     {
#         "air_pressure": 1013.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T18:59:01.400634Z",
#         "humidity": 52,
#         "id": 4963906624684032,
#         "max_temp": 5.605,
#         "min_temp": -0.63,
#         "predictability": 82,
#         "the_temp": 4.85,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 332.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 10.236222858506324
#     },
#     {
#         "air_pressure": 1013.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T15:59:00.760719Z",
#         "humidity": 52,
#         "id": 5277173217755136,
#         "max_temp": 5.605,
#         "min_temp": -0.63,
#         "predictability": 82,
#         "the_temp": 4.85,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 332.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 10.236222858506324
#     },
#     {
#         "air_pressure": 1019.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T12:59:01.422144Z",
#         "humidity": 50,
#         "id": 6411869217619968,
#         "max_temp": 5.655,
#         "min_temp": -0.02500000000000001,
#         "predictability": 82,
#         "the_temp": 4.84,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 333.5,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 9.838545295474429
#     },
#     {
#         "air_pressure": 1019.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T09:59:01.619035Z",
#         "humidity": 52,
#         "id": 6322544937271296,
#         "max_temp": 6.73,
#         "min_temp": -0.29500000000000004,
#         "predictability": 77,
#         "the_temp": 4.84,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "hr",
#         "weather_state_name": "Heavy Rain",
#         "wind_direction": 316.5,
#         "wind_direction_compass": "NW",
#         "wind_speed": 7.95854529547443
#     },
#     {
#         "air_pressure": 1021.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T06:59:01.600704Z",
#         "humidity": 53,
#         "id": 5301029647155200,
#         "max_temp": 7.27,
#         "min_temp": -0.3,
#         "predictability": 71,
#         "the_temp": 6.03,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "hc",
#         "weather_state_name": "Heavy Cloud",
#         "wind_direction": 314.5,
#         "wind_direction_compass": "NW",
#         "wind_speed": 7.92126302394019
#     },
#     {
#         "air_pressure": 1021.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T03:59:01.319468Z",
#         "humidity": 53,
#         "id": 4877356020793344,
#         "max_temp": 7.255000000000001,
#         "min_temp": -0.26,
#         "predictability": 71,
#         "the_temp": 6.03,
#         "visibility": 9.736265211166785,
#         "weather_state_abbr": "hc",
#         "weather_state_name": "Heavy Cloud",
#         "wind_direction": 314.5,
#         "wind_direction_compass": "NW",
#         "wind_speed": 7.911263023940188
#     },
#     {
#         "air_pressure": 1017.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-30T00:59:02.404428Z",
#         "humidity": 55,
#         "id": 4971961198313472,
#         "max_temp": 7.390000000000001,
#         "min_temp": 0.08000000000000002,
#         "predictability": 77,
#         "the_temp": 5.82,
#         "visibility": 9.736265211166785,
#         "weather_state_abbr": "hr",
#         "weather_state_name": "Heavy Rain",
#         "wind_direction": 318.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 7.706210530501869
#     },
#     {
#         "air_pressure": 1017.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T21:59:04.011019Z",
#         "humidity": 55,
#         "id": 5368532440186880,
#         "max_temp": 7.390000000000001,
#         "min_temp": 0.08000000000000002,
#         "predictability": 77,
#         "the_temp": 5.82,
#         "visibility": 9.736265211166785,
#         "weather_state_abbr": "hr",
#         "weather_state_name": "Heavy Rain",
#         "wind_direction": 318.0,
#         "wind_direction_compass": "NW",
#         "wind_speed": 7.706210530501869
#     },
#     {
#         "air_pressure": 1028.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T18:59:04.105164Z",
#         "humidity": 57,
#         "id": 5244077307068416,
#         "max_temp": 6.755,
#         "min_temp": -0.16999999999999998,
#         "predictability": 73,
#         "the_temp": 4.38,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "s",
#         "weather_state_name": "Showers",
#         "wind_direction": 334.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 6.296402012248469
#     },
#     {
#         "air_pressure": 1028.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T15:59:05.600932Z",
#         "humidity": 57,
#         "id": 6085203702317056,
#         "max_temp": 6.755,
#         "min_temp": -0.16999999999999998,
#         "predictability": 73,
#         "the_temp": 4.38,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "s",
#         "weather_state_name": "Showers",
#         "wind_direction": 334.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 6.296402012248469
#     },
#     {
#         "air_pressure": 1025.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T12:59:03.897471Z",
#         "humidity": 56,
#         "id": 5836688573071360,
#         "max_temp": 6.85,
#         "min_temp": -0.5349999999999999,
#         "predictability": 73,
#         "the_temp": 4.61,
#         "visibility": 9.999726596675416,
#         "weather_state_abbr": "s",
#         "weather_state_name": "Showers",
#         "wind_direction": 333.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 6.268440308597789
#     },
#     {
#         "air_pressure": 1025.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T09:59:05.510549Z",
#         "humidity": 56,
#         "id": 6262054852755456,
#         "max_temp": 4.785,
#         "min_temp": 0.035,
#         "predictability": 73,
#         "the_temp": 4.61,
#         "visibility": 9.323053368328958,
#         "weather_state_abbr": "s",
#         "weather_state_name": "Showers",
#         "wind_direction": 345.5,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 8.078440308597788
#     },
#     {
#         "air_pressure": 1026.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T06:59:05.058511Z",
#         "humidity": 57,
#         "id": 5709461407662080,
#         "max_temp": 4.0600000000000005,
#         "min_temp": -0.51,
#         "predictability": 82,
#         "the_temp": 3.69,
#         "visibility": 9.323053368328958,
#         "weather_state_abbr": "h",
#         "weather_state_name": "Hail",
#         "wind_direction": 348.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 8.075333452636603
#     },
#     {
#         "air_pressure": 1026.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T03:59:04.714219Z",
#         "humidity": 39,
#         "id": 5187508158595072,
#         "max_temp": 3.99,
#         "min_temp": -1.47,
#         "predictability": 90,
#         "the_temp": 3.69,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 343.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 4.380666905273205
#     },
#     {
#         "air_pressure": 1023.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-29T00:59:05.300939Z",
#         "humidity": 39,
#         "id": 4883547149041664,
#         "max_temp": 8.0,
#         "min_temp": -1.72,
#         "predictability": 90,
#         "the_temp": 2.81,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 336.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 4.678925077547125
#     },
#     {
#         "air_pressure": 1023.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T21:59:06.818630Z",
#         "humidity": 39,
#         "id": 4842392067768320,
#         "max_temp": 8.0,
#         "min_temp": -1.72,
#         "predictability": 90,
#         "the_temp": 2.81,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 336.0,
#         "wind_direction_compass": "NNW",
#         "wind_speed": 4.678925077547125
#     },
#     {
#         "air_pressure": 990.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T18:59:06.631692Z",
#         "humidity": 82,
#         "id": 5160248403820544,
#         "max_temp": 9.49,
#         "min_temp": 2.36,
#         "predictability": 90,
#         "the_temp": 6.82,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 238.0,
#         "wind_direction_compass": "WSW",
#         "wind_speed": 5.909240038177046
#     },
#     {
#         "air_pressure": 990.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T15:59:06.827816Z",
#         "humidity": 82,
#         "id": 6681043844202496,
#         "max_temp": 9.49,
#         "min_temp": 2.36,
#         "predictability": 90,
#         "the_temp": 6.82,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 238.0,
#         "wind_direction_compass": "WSW",
#         "wind_speed": 5.909240038177046
#     },
#     {
#         "air_pressure": 990.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T12:59:09.029435Z",
#         "humidity": 62,
#         "id": 4588336162275328,
#         "max_temp": 9.45,
#         "min_temp": 2.62,
#         "predictability": 90,
#         "the_temp": 9.45,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 206.0,
#         "wind_direction_compass": "SSW",
#         "wind_speed": 5.2443728624830985
#     },
#     {
#         "air_pressure": 990.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T09:59:08.602708Z",
#         "humidity": 62,
#         "id": 4571673031344128,
#         "max_temp": 9.45,
#         "min_temp": 2.62,
#         "predictability": 90,
#         "the_temp": 9.45,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 206.0,
#         "wind_direction_compass": "SSW",
#         "wind_speed": 5.2443728624830985
#     },
#     {
#         "air_pressure": 1020.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T06:59:07.396695Z",
#         "humidity": 39,
#         "id": 4907330530443264,
#         "max_temp": 6.35,
#         "min_temp": -0.52,
#         "predictability": 90,
#         "the_temp": 2.56,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 352.0,
#         "wind_direction_compass": "N",
#         "wind_speed": 5.294082557862085
#     },
#     {
#         "air_pressure": 1020.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T03:59:08.111543Z",
#         "humidity": 39,
#         "id": 5792921212157952,
#         "max_temp": 6.35,
#         "min_temp": -0.52,
#         "predictability": 90,
#         "the_temp": 2.56,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 352.0,
#         "wind_direction_compass": "N",
#         "wind_speed": 5.294082557862085
#     },
#     {
#         "air_pressure": 1008.0,
#         "applicable_date": "2021-04-05",
#         "created": "2021-03-28T00:59:08.298544Z",
#         "humidity": 66,
#         "id": 5422777877135360,
#         "max_temp": 3.08,
#         "min_temp": -1.16,
#         "predictability": 90,
#         "the_temp": 3.08,
#         "visibility": null,
#         "weather_state_abbr": "sn",
#         "weather_state_name": "Snow",
#         "wind_direction": 35.0,
#         "wind_direction_compass": "NE",
#         "wind_speed": 5.3065099817068315
#     }
# ]

# %% [markdown]
# ## Open library API

# %%
url = 'http://openlibrary.org/recentchanges.json?limit=10&bots=false'
r = requests.get(url)
display(r.status_code)
print(json.dumps(r.json(), sort_keys=True, indent=4))
# Out:
# 200
# [
#     {
#         "author": {
#             "key": "/people/scorchedwing"
#         },
#         "changes": [
#             {
#                 "key": "/people/scorchedwing/preferences",
#                 "revision": 1
#             }
#         ],
#         "comment": "updating user preferences",
#         "data": {},
#         "id": "82375381",
#         "ip": null,
#         "kind": "update",
#         "timestamp": "2021-04-05T19:00:37.787683"
#     },
#     {
#         "author": {
#             "key": "/people/scorchedwing"
#         },
#         "changes": [
#             {
#                 "key": "/people/scorchedwing",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/scorchedwing/usergroup",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/scorchedwing/permission",
#                 "revision": 1
#             }
#         ],
#         "comment": "Created new account.",
#         "data": {},
#         "id": "82375380",
#         "ip": null,
#         "kind": "new-account",
#         "timestamp": "2021-04-05T19:00:37.622125"
#     },
#     {
#         "author": {
#             "key": "/people/sakshi219640"
#         },
#         "changes": [
#             {
#                 "key": "/people/sakshi219640/preferences",
#                 "revision": 1
#             }
#         ],
#         "comment": "updating user preferences",
#         "data": {},
#         "id": "82375379",
#         "ip": null,
#         "kind": "update",
#         "timestamp": "2021-04-05T19:00:04.911487"
#     },
#     {
#         "author": {
#             "key": "/people/sakshi219640"
#         },
#         "changes": [
#             {
#                 "key": "/people/sakshi219640",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/sakshi219640/usergroup",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/sakshi219640/permission",
#                 "revision": 1
#             }
#         ],
#         "comment": "Created new account.",
#         "data": {},
#         "id": "82375378",
#         "ip": null,
#         "kind": "new-account",
#         "timestamp": "2021-04-05T19:00:04.729942"
#     },
#     {
#         "author": {
#             "key": "/people/sduvall"
#         },
#         "changes": [
#             {
#                 "key": "/people/sduvall/preferences",
#                 "revision": 1
#             }
#         ],
#         "comment": "updating user preferences",
#         "data": {},
#         "id": "82375377",
#         "ip": null,
#         "kind": "update",
#         "timestamp": "2021-04-05T18:59:23.862512"
#     },
#     {
#         "author": {
#             "key": "/people/sduvall"
#         },
#         "changes": [
#             {
#                 "key": "/people/sduvall",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/sduvall/usergroup",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/sduvall/permission",
#                 "revision": 1
#             }
#         ],
#         "comment": "Created new account.",
#         "data": {},
#         "id": "82375376",
#         "ip": null,
#         "kind": "new-account",
#         "timestamp": "2021-04-05T18:59:23.700804"
#     },
#     {
#         "author": {
#             "key": "/people/golondrina1414"
#         },
#         "changes": [
#             {
#                 "key": "/people/golondrina1414/preferences",
#                 "revision": 1
#             }
#         ],
#         "comment": "updating user preferences",
#         "data": {},
#         "id": "82375375",
#         "ip": null,
#         "kind": "update",
#         "timestamp": "2021-04-05T18:58:40.888518"
#     },
#     {
#         "author": {
#             "key": "/people/golondrina1414"
#         },
#         "changes": [
#             {
#                 "key": "/people/golondrina1414",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/golondrina1414/usergroup",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/golondrina1414/permission",
#                 "revision": 1
#             }
#         ],
#         "comment": "Created new account.",
#         "data": {},
#         "id": "82375374",
#         "ip": null,
#         "kind": "new-account",
#         "timestamp": "2021-04-05T18:58:40.745999"
#     },
#     {
#         "author": {
#             "key": "/people/isadoraruiz6974"
#         },
#         "changes": [
#             {
#                 "key": "/people/isadoraruiz6974/preferences",
#                 "revision": 1
#             }
#         ],
#         "comment": "updating user preferences",
#         "data": {},
#         "id": "82375373",
#         "ip": null,
#         "kind": "update",
#         "timestamp": "2021-04-05T18:58:05.898659"
#     },
#     {
#         "author": {
#             "key": "/people/isadoraruiz6974"
#         },
#         "changes": [
#             {
#                 "key": "/people/isadoraruiz6974",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/isadoraruiz6974/usergroup",
#                 "revision": 1
#             },
#             {
#                 "key": "/people/isadoraruiz6974/permission",
#                 "revision": 1
#             }
#         ],
#         "comment": "Created new account.",
#         "data": {},
#         "id": "82375372",
#         "ip": null,
#         "kind": "new-account",
#         "timestamp": "2021-04-05T18:58:05.728620"
#     }
# ]

# %%
url = 'http://openlibrary.org/search.json?q=python'
re = requests.get(url)
display(re.status_code)
print(json.dumps(re.json(), sort_keys=True, indent=4))
# Out:
# 200
# {
#     "docs": [
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "contributor": [
#                 "Chapman, Graham, 1941?-",
#                 "Monty Python (Corporate Author)",
#                 "Chapman, Graham."
#             ],
#             "ddc": [
#                 "791.437",
#                 "791.4372"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 7,
#             "edition_key": [
#                 "OL9757850M",
#                 "OL7525861M",
#                 "OL17896351M",
#                 "OL7561923M",
#                 "OL8619612M",
#                 "OL4435062M",
#                 "OL22459268M"
#             ],
#             "first_publish_year": 1979,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "24560",
#                 "471894",
#                 "140553",
#                 "486454"
#             ],
#             "id_librarything": [
#                 "1109482",
#                 "8988260"
#             ],
#             "isbn": [
#                 "9781858482798",
#                 "9781858482781",
#                 "1858482798",
#                 "9780448165684",
#                 "9780413741301",
#                 "0413465500",
#                 "185848278X",
#                 "9780413465504",
#                 "0441482406",
#                 "0413741303",
#                 "0448165686",
#                 "9780441482405"
#             ],
#             "key": "/works/OL8088577W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1602935259,
#             "lcc": [
#                 "PN-1997.00000000.L575 2001",
#                 "PN-1997.00000000.L575 1979"
#             ],
#             "lccn": [
#                 "79088137",
#                 "79118255"
#             ],
#             "oclc": [
#                 "6392465",
#                 "5382213"
#             ],
#             "publish_date": [
#                 "2001",
#                 "August 1979",
#                 "1979"
#             ],
#             "publish_place": [
#                 "New York",
#                 "London"
#             ],
#             "publish_year": [
#                 2001,
#                 1979
#             ],
#             "publisher": [
#                 "Putnam Pub Group",
#                 "Eyre Methuen",
#                 "Methuen",
#                 "Listen for Pleasure",
#                 "Penguin Putnam",
#                 "F. Jordan Books"
#             ],
#             "seed": [
#                 "/books/OL9757850M",
#                 "/books/OL7525861M",
#                 "/books/OL17896351M",
#                 "/books/OL7561923M",
#                 "/books/OL8619612M",
#                 "/books/OL4435062M",
#                 "/books/OL22459268M",
#                 "/works/OL8088577W",
#                 "/subjects/life_of_brian._[motion_picture]",
#                 "/authors/OL2693119A"
#             ],
#             "subject": [
#                 "Life of Brian. [Motion picture]"
#             ],
#             "text": [
#                 "OL9757850M",
#                 "OL7525861M",
#                 "OL17896351M",
#                 "OL7561923M",
#                 "OL8619612M",
#                 "OL4435062M",
#                 "OL22459268M",
#                 "9781858482798",
#                 "9781858482781",
#                 "1858482798",
#                 "9780448165684",
#                 "9780413741301",
#                 "0413465500",
#                 "185848278X",
#                 "9780413465504",
#                 "0441482406",
#                 "0413741303",
#                 "0448165686",
#                 "9780441482405",
#                 "Monty Python",
#                 "6392465",
#                 "5382213",
#                 "Chapman, Graham, 1941?-",
#                 "Monty Python (Corporate Author)",
#                 "Chapman, Graham.",
#                 "OL2693119A",
#                 "Life of Brian. [Motion picture]",
#                 "Life of Brian",
#                 "/works/OL8088577W",
#                 "written and staring Graham Chapman ... [et al.].",
#                 "written by and starring Graham Chapman ... [et al.].",
#                 "Putnam Pub Group",
#                 "Eyre Methuen",
#                 "Methuen",
#                 "Listen for Pleasure",
#                 "Penguin Putnam",
#                 "F. Jordan Books",
#                 "Monty Python's life of Brian",
#                 "The life of Brian",
#                 "Life of Brian.",
#                 "Monty Python's The life of Brian (of Nazareth)",
#                 "Life of Brian. [Motion picture]",
#                 "Life of Brian (Motion picture)",
#                 "Monty Python's the Life of Brian (Of Nazareth)",
#                 "79088137",
#                 "79118255",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Life of Brian",
#             "title_suggest": "Life of Brian",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "contributor": [
#                 "Gilliam, Terry.",
#                 "Jones, Terry, 1942-",
#                 "Idle, Eric.",
#                 "Chapman, Graham, 1941-1989.",
#                 "Cleese, John.",
#                 "Palin, Michael."
#             ],
#             "cover_edition_key": "OL7966134M",
#             "cover_i": 4699714,
#             "ebook_count_i": 1,
#             "edition_count": 6,
#             "edition_key": [
#                 "OL7498491M",
#                 "OL23077756M",
#                 "OL7966134M",
#                 "OL9399915M",
#                 "OL7480605M",
#                 "OL12890047M"
#             ],
#             "first_publish_year": 1977,
#             "has_fulltext": true,
#             "ia": [
#                 "montypythonholyg0000clee"
#             ],
#             "ia_box_id": [
#                 "IA1192316"
#             ],
#             "ia_collection_s": "printdisabled;fav-pict13;fav-james_silk;internetarchivebooks;occidentalcollegelibrary-ol;inlibrary;fav-filmcrazy;china;fav-barry_o_apos_neill;fav-joy5433",
#             "id_goodreads": [
#                 "2946472",
#                 "471891",
#                 "4496827",
#                 "140538"
#             ],
#             "id_librarything": [
#                 "1623503"
#             ],
#             "isbn": [
#                 "9780413773944",
#                 "6308618837",
#                 "9786308618833",
#                 "0413773949",
#                 "0416003419",
#                 "0749311428",
#                 "1575000156",
#                 "9781575000152",
#                 "9780749311421",
#                 "9780416003413"
#             ],
#             "key": "/works/OL8088581W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1597854417,
#             "lccn": [
#                 "07781574"
#             ],
#             "lending_edition_s": "OL7480605M",
#             "lending_identifier_s": "montypythonholyg0000clee",
#             "oclc": [
#                 "54683056"
#             ],
#             "printdisabled_s": "OL7480605M",
#             "public_scan_b": false,
#             "publish_date": [
#                 "March 4, 2004",
#                 "1992",
#                 "1980",
#                 "July 31, 2004",
#                 "October 1977",
#                 "October 1996"
#             ],
#             "publish_place": [
#                 "New York, N.Y"
#             ],
#             "publish_year": [
#                 1977,
#                 1992,
#                 1980,
#                 2004,
#                 1996
#             ],
#             "publisher": [
#                 "Routledge",
#                 "Heinemann",
#                 "Methuen Drama",
#                 "Methuen",
#                 "TV Books",
#                 "BMG SPECIAL PRODUCTS"
#             ],
#             "seed": [
#                 "/books/OL7498491M",
#                 "/books/OL23077756M",
#                 "/books/OL7966134M",
#                 "/books/OL9399915M",
#                 "/books/OL7480605M",
#                 "/books/OL12890047M",
#                 "/works/OL8088581W",
#                 "/authors/OL2693119A"
#             ],
#             "subject": [
#                 "Accessible book",
#                 "Protected DAISY"
#             ],
#             "text": [
#                 "OL7498491M",
#                 "OL23077756M",
#                 "OL7966134M",
#                 "OL9399915M",
#                 "OL7480605M",
#                 "OL12890047M",
#                 "9780413773944",
#                 "6308618837",
#                 "9786308618833",
#                 "0413773949",
#                 "0416003419",
#                 "0749311428",
#                 "1575000156",
#                 "9781575000152",
#                 "9780749311421",
#                 "9780416003413",
#                 "Monty Python",
#                 "Gilliam, Terry.",
#                 "Jones, Terry, 1942-",
#                 "Idle, Eric.",
#                 "Chapman, Graham, 1941-1989.",
#                 "Cleese, John.",
#                 "Palin, Michael.",
#                 "54683056",
#                 "montypythonholyg0000clee",
#                 "OL2693119A",
#                 "Accessible book",
#                 "Protected DAISY",
#                 "a first draft",
#                 "Monty Python & the Holy Grail",
#                 "/works/OL8088581W",
#                 "by Graham Chapman, Terry Jones, Terry Gilliam, Michael Palin, Eric Idle & John Cleese.",
#                 "Routledge",
#                 "Heinemann",
#                 "Methuen Drama",
#                 "Methuen",
#                 "TV Books",
#                 "BMG SPECIAL PRODUCTS",
#                 "Monty Python's second film",
#                 "Monty Python and the Holy Grail",
#                 "M\u00f8nti Pyth\u00f8n ik den H\u00f8lie Gr\u00e4ilen (B\u00f8k).",
#                 "Monty Python and the Holy Grail (Book).",
#                 "07781574",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Monty Python & the Holy Grail",
#             "title_suggest": "Monty Python & the Holy Grail",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "contributor": [
#                 "Chapman, Graham, 1941?-",
#                 "Chapman, Graham, 1941-1989."
#             ],
#             "cover_i": 7278049,
#             "ddc": [
#                 "791.43",
#                 "791.4372"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 6,
#             "edition_key": [
#                 "OL8619614M",
#                 "OL2906519M",
#                 "OL22111871M",
#                 "OL8619613M",
#                 "OL23090738M",
#                 "OL12945627M"
#             ],
#             "first_publish_year": 1983,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "471895",
#                 "4680735"
#             ],
#             "id_librarything": [
#                 "587333",
#                 "1460781"
#             ],
#             "isbn": [
#                 "9781858482811",
#                 "9781858482804",
#                 "1858482801",
#                 "6309213792",
#                 "0394624742",
#                 "9780394624747",
#                 "9786309213792",
#                 "185848281X",
#                 "0413533808",
#                 "9780413533807"
#             ],
#             "key": "/works/OL128296W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1604119089,
#             "lcc": [
#                 "PN-1997.00000000.M424 1983"
#             ],
#             "lccn": [
#                 "83080495",
#                 "84136118"
#             ],
#             "publish_date": [
#                 "August 31, 1994",
#                 "1983"
#             ],
#             "publish_place": [
#                 "New York",
#                 "London"
#             ],
#             "publish_year": [
#                 1994,
#                 1983
#             ],
#             "publisher": [
#                 "Methuen",
#                 "MSI MUSIC",
#                 "Listen for Pleasure",
#                 "Grove Press"
#             ],
#             "seed": [
#                 "/books/OL8619614M",
#                 "/books/OL2906519M",
#                 "/books/OL22111871M",
#                 "/books/OL8619613M",
#                 "/books/OL23090738M",
#                 "/books/OL12945627M",
#                 "/works/OL128296W",
#                 "/subjects/meaning_of_life_(motion_picture)",
#                 "/authors/OL2693119A"
#             ],
#             "subject": [
#                 "Meaning of life (Motion picture)"
#             ],
#             "text": [
#                 "OL8619614M",
#                 "OL2906519M",
#                 "OL22111871M",
#                 "OL8619613M",
#                 "OL23090738M",
#                 "OL12945627M",
#                 "9781858482811",
#                 "9781858482804",
#                 "1858482801",
#                 "6309213792",
#                 "0394624742",
#                 "9780394624747",
#                 "9786309213792",
#                 "185848281X",
#                 "0413533808",
#                 "9780413533807",
#                 "Monty Python",
#                 "Chapman, Graham, 1941?-",
#                 "Chapman, Graham, 1941-1989.",
#                 "OL2693119A",
#                 "Meaning of life (Motion picture)",
#                 "Monty Python's the meaning of life",
#                 "/works/OL128296W",
#                 "written and performed by Graham Chapman ... (et al.).",
#                 "written and performed by Graham Chapman ... [et al.].",
#                 "Methuen",
#                 "MSI MUSIC",
#                 "Listen for Pleasure",
#                 "Grove Press",
#                 "The meaning of life",
#                 "Meaning of Life",
#                 "Meaning of life (Motion picture)",
#                 "Meaning of life",
#                 "83080495",
#                 "84136118",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Monty Python's the meaning of life",
#             "title_suggest": "Monty Python's the meaning of life",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL7902680A"
#             ],
#             "author_name": [
#                 "Andre Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 6,
#             "edition_key": [
#                 "OL28082436M",
#                 "OL30166877M",
#                 "OL30166321M",
#                 "OL28082126M",
#                 "OL28082201M",
#                 "OL28082414M"
#             ],
#             "first_publish_year": 2020,
#             "has_fulltext": false,
#             "isbn": [
#                 "1000093689",
#                 "9780367472245",
#                 "1000093700",
#                 "1000093727",
#                 "9781000093704",
#                 "9781000093728",
#                 "0367472244",
#                 "0367472287",
#                 "1003034233",
#                 "9781000093681",
#                 "9780367472283",
#                 "9781003034230"
#             ],
#             "key": "/works/OL20754316W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1600229952,
#             "lcc": [
#                 "HV-6431.00000000"
#             ],
#             "publish_date": [
#                 "2020"
#             ],
#             "publish_year": [
#                 2020
#             ],
#             "publisher": [
#                 "Taylor & Francis Group"
#             ],
#             "seed": [
#                 "/books/OL28082436M",
#                 "/books/OL30166877M",
#                 "/books/OL30166321M",
#                 "/books/OL28082126M",
#                 "/books/OL28082201M",
#                 "/books/OL28082414M",
#                 "/works/OL20754316W",
#                 "/authors/OL7902680A"
#             ],
#             "text": [
#                 "OL28082436M",
#                 "OL30166877M",
#                 "OL30166321M",
#                 "OL28082126M",
#                 "OL28082201M",
#                 "OL28082414M",
#                 "1000093689",
#                 "9780367472245",
#                 "1000093700",
#                 "1000093727",
#                 "9781000093704",
#                 "9781000093728",
#                 "0367472244",
#                 "0367472287",
#                 "1003034233",
#                 "9781000093681",
#                 "9780367472283",
#                 "9781003034230",
#                 "Andre Python",
#                 "OL7902680A",
#                 "Debunking Seven Terrorism Myths Using Statistics",
#                 "/works/OL20754316W",
#                 "Taylor & Francis Group"
#             ],
#             "title": "Debunking Seven Terrorism Myths Using Statistics",
#             "title_suggest": "Debunking Seven Terrorism Myths Using Statistics",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "cover_edition_key": "OL7480316M",
#             "cover_i": 261609,
#             "ebook_count_i": 0,
#             "edition_count": 3,
#             "edition_key": [
#                 "OL7479941M",
#                 "OL7480317M",
#                 "OL7480316M"
#             ],
#             "first_publish_year": 1989,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "972211",
#                 "1488380",
#                 "1118112"
#             ],
#             "id_librarything": [
#                 "6487222",
#                 "6487654"
#             ],
#             "isbn": [
#                 "0413741109",
#                 "0413625508",
#                 "9780413741004",
#                 "0413741001",
#                 "9780413741103",
#                 "9780413625502"
#             ],
#             "key": "/works/OL8089232W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1588964766,
#             "publish_date": [
#                 "January 2004",
#                 "October 5, 1989"
#             ],
#             "publish_year": [
#                 2004,
#                 1989
#             ],
#             "publisher": [
#                 "Methuen",
#                 "Methuen Publishing"
#             ],
#             "seed": [
#                 "/books/OL7479941M",
#                 "/books/OL7480317M",
#                 "/books/OL7480316M",
#                 "/works/OL8089232W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL7479941M",
#                 "OL7480317M",
#                 "OL7480316M",
#                 "0413741109",
#                 "0413625508",
#                 "9780413741004",
#                 "0413741001",
#                 "9780413741103",
#                 "9780413625502",
#                 "Monty Python",
#                 "OL2693119A",
#                 "Just the Words",
#                 "/works/OL8089232W",
#                 "Methuen",
#                 "Methuen Publishing",
#                 "Just the words",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Just the Words",
#             "title_suggest": "Just the Words",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 3,
#             "edition_key": [
#                 "OL9343990M",
#                 "OL8619611M",
#                 "OL12693454M"
#             ],
#             "first_publish_year": 2000,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "1411544"
#             ],
#             "id_librarything": [
#                 "1460784"
#             ],
#             "isbn": [
#                 "9781858482767",
#                 "6304402619",
#                 "9781858482774",
#                 "9786304402610",
#                 "1858482763",
#                 "1858482771"
#             ],
#             "key": "/works/OL8088566W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1588965411,
#             "publish_date": [
#                 "July 31, 2000"
#             ],
#             "publish_year": [
#                 2000
#             ],
#             "publisher": [
#                 "ARISTA RECORDS",
#                 "Listen for Pleasure"
#             ],
#             "seed": [
#                 "/books/OL9343990M",
#                 "/books/OL8619611M",
#                 "/books/OL12693454M",
#                 "/works/OL8088566W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL9343990M",
#                 "OL8619611M",
#                 "OL12693454M",
#                 "9781858482767",
#                 "6304402619",
#                 "9781858482774",
#                 "9786304402610",
#                 "1858482763",
#                 "1858482771",
#                 "Monty Python",
#                 "OL2693119A",
#                 "Contractual obligation",
#                 "/works/OL8088566W",
#                 "ARISTA RECORDS",
#                 "Listen for Pleasure",
#                 "Monty Python's \"Contractual obligation\"",
#                 "Contractual Obligation",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Contractual obligation",
#             "title_suggest": "Contractual obligation",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 2,
#             "edition_key": [
#                 "OL8619608M",
#                 "OL8619607M"
#             ],
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "1440177",
#                 "1440174"
#             ],
#             "id_librarything": [
#                 "824514"
#             ],
#             "isbn": [
#                 "9781858482705",
#                 "9781858482712",
#                 "1858482712",
#                 "1858482704"
#             ],
#             "key": "/works/OL8088578W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1400177827,
#             "oclc": [
#                 "655703045"
#             ],
#             "publisher": [
#                 "Listen for pleasure"
#             ],
#             "seed": [
#                 "/books/OL8619608M",
#                 "/books/OL8619607M",
#                 "/works/OL8088578W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL8619608M",
#                 "OL8619607M",
#                 "9781858482705",
#                 "9781858482712",
#                 "1858482712",
#                 "1858482704",
#                 "Monty Python",
#                 "655703045",
#                 "OL2693119A",
#                 "Matching tie and handkerchief",
#                 "/works/OL8088578W",
#                 "Listen for pleasure",
#                 "A Matching tie and handkerchief",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Matching tie and handkerchief",
#             "title_suggest": "Matching tie and handkerchief",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "contributor": [
#                 "Graham Chapman (Reader)",
#                 "Michael Palin (Reader)",
#                 "John Cleese (Reader)",
#                 "Terry Jones (Reader)",
#                 "Eric Idle (Reader)",
#                 "Terry Gilliam (Reader)"
#             ],
#             "cover_edition_key": "OL8905551M",
#             "cover_i": 2010890,
#             "ebook_count_i": 0,
#             "edition_count": 2,
#             "edition_key": [
#                 "OL7480545M",
#                 "OL8905551M"
#             ],
#             "first_publish_year": 1998,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "1116367",
#                 "661381"
#             ],
#             "id_librarything": [
#                 "6487229",
#                 "6487467"
#             ],
#             "isbn": [
#                 "0413772802",
#                 "9780413772800",
#                 "1602830568",
#                 "9781602830561"
#             ],
#             "key": "/works/OL8088580W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1582900157,
#             "publish_date": [
#                 "October 1, 1998",
#                 "June 15, 2007"
#             ],
#             "publish_year": [
#                 1998,
#                 2007
#             ],
#             "publisher": [
#                 "Methuen Publishing Ltd",
#                 "BBC Audiobooks America"
#             ],
#             "seed": [
#                 "/books/OL7480545M",
#                 "/books/OL8905551M",
#                 "/works/OL8088580W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL7480545M",
#                 "OL8905551M",
#                 "0413772802",
#                 "9780413772800",
#                 "1602830568",
#                 "9781602830561",
#                 "Monty Python",
#                 "Graham Chapman (Reader)",
#                 "Michael Palin (Reader)",
#                 "John Cleese (Reader)",
#                 "Terry Jones (Reader)",
#                 "Eric Idle (Reader)",
#                 "Terry Gilliam (Reader)",
#                 "OL2693119A",
#                 "Just the Words",
#                 "Greatest Skits",
#                 "Monty Python's Flying Circus",
#                 "/works/OL8088580W",
#                 "Methuen Publishing Ltd",
#                 "BBC Audiobooks America",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Monty Python's Flying Circus",
#             "title_suggest": "Monty Python's Flying Circus",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "contributor": [
#                 "Chapman, Graham, 1941?-"
#             ],
#             "cover_edition_key": "OL7479544M",
#             "ddc": [
#                 "791.437"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 2,
#             "edition_key": [
#                 "OL4473543M",
#                 "OL7479544M"
#             ],
#             "first_publish_year": 1977,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "586997"
#             ],
#             "id_librarything": [
#                 "1623503"
#             ],
#             "id_libris": [
#                 "5561139"
#             ],
#             "isbn": [
#                 "0413385205",
#                 "9780413385208"
#             ],
#             "key": "/works/OL8088573W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1564528480,
#             "lcc": [
#                 "PN-1997.00000000.M68 M66"
#             ],
#             "lccn": [
#                 "79300804"
#             ],
#             "oclc": [
#                 "3962889"
#             ],
#             "publish_date": [
#                 "1977"
#             ],
#             "publish_place": [
#                 "London",
#                 "London, England"
#             ],
#             "publish_year": [
#                 1977
#             ],
#             "publisher": [
#                 "Methuen",
#                 "Eyre Methuen"
#             ],
#             "seed": [
#                 "/books/OL4473543M",
#                 "/books/OL7479544M",
#                 "/works/OL8088573W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL4473543M",
#                 "OL7479544M",
#                 "0413385205",
#                 "9780413385208",
#                 "Monty Python",
#                 "3962889",
#                 "Chapman, Graham, 1941?-",
#                 "OL2693119A",
#                 "A First Draft",
#                 "a first draft",
#                 "Monty Python's Second Film",
#                 "/works/OL8088573W",
#                 "by Graham Chapman ... [et al.].",
#                 "Methuen",
#                 "Eyre Methuen",
#                 "Monty Python's second film",
#                 "Monty Python and the Holy Grail (Book).",
#                 "M\u00f8nti Pyth\u00f8n ik den H\u00f8lie Gr\u00e4ilen (B\u00f8k).",
#                 "Monty Python and the Holy Grail. [Motion Picture]",
#                 "79300804",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Monty Python's Second Film",
#             "title_suggest": "Monty Python's Second Film",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL7232013A"
#             ],
#             "author_name": [
#                 "Python Zem"
#             ],
#             "cover_edition_key": "OL25652011M",
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL25652011M"
#             ],
#             "first_publish_year": 2015,
#             "has_fulltext": false,
#             "key": "/works/OL17081563W",
#             "last_modified_i": 1423538011,
#             "publish_date": [
#                 "2015"
#             ],
#             "publish_year": [
#                 2015
#             ],
#             "publisher": [
#                 "Python Zem"
#             ],
#             "seed": [
#                 "/books/OL25652011M",
#                 "/works/OL17081563W",
#                 "/authors/OL7232013A"
#             ],
#             "text": [
#                 "OL25652011M",
#                 "Python Zem",
#                 "OL7232013A",
#                 "PANERAI",
#                 "/works/OL17081563W",
#                 "Python Zem"
#             ],
#             "title": "PANERAI",
#             "title_suggest": "PANERAI",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "cover_edition_key": "OL26729368M",
#             "cover_i": 8386705,
#             "ebook_count_i": 1,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL26729368M"
#             ],
#             "first_publish_year": 1989,
#             "has_fulltext": true,
#             "ia": [
#                 "montypythonsflyi0000mont"
#             ],
#             "ia_box_id": [
#                 "IA1746704"
#             ],
#             "ia_collection_s": "printdisabled;fav-popo55;fav-sprotte99;inlibrary;internetarchivebooks",
#             "isbn": [
#                 "3251002228",
#                 "9783251002221"
#             ],
#             "key": "/works/OL19072364W",
#             "last_modified_i": 1588964336,
#             "lending_edition_s": "OL26729368M",
#             "lending_identifier_s": "montypythonsflyi0000mont",
#             "printdisabled_s": "OL26729368M",
#             "public_scan_b": false,
#             "publish_date": [
#                 "Feb 23, 1989"
#             ],
#             "publish_year": [
#                 1989
#             ],
#             "publisher": [
#                 "METHUEN"
#             ],
#             "seed": [
#                 "/books/OL26729368M",
#                 "/works/OL19072364W",
#                 "/subjects/englisch",
#                 "/subjects/monty_python",
#                 "/subjects/filmkomo\u0098die",
#                 "/subjects/nonsens_(literatur)",
#                 "/authors/OL2693119A"
#             ],
#             "subject": [
#                 "Filmkomo\u0098die",
#                 "Accessible book",
#                 "Monty Python",
#                 "Nonsens (Literatur)",
#                 "Englisch",
#                 "Protected DAISY"
#             ],
#             "subtitle": "S\u00e4mtliche Worte. Band 1",
#             "text": [
#                 "OL26729368M",
#                 "S\u00e4mtliche Worte. Band 1",
#                 "Monty Python",
#                 "montypythonsflyi0000mont",
#                 "3251002228",
#                 "9783251002221",
#                 "OL2693119A",
#                 "Filmkomo\u0098die",
#                 "Accessible book",
#                 "Monty Python",
#                 "Nonsens (Literatur)",
#                 "Englisch",
#                 "Protected DAISY",
#                 "Monty Python's Flying Circus",
#                 "/works/OL19072364W",
#                 "METHUEN",
#                 "Monty Python s Flying Circus, S\u00e4mtliche Worte. Band 1",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Monty Python's Flying Circus",
#             "title_suggest": "Monty Python's Flying Circus",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL7463482A"
#             ],
#             "author_name": [
#                 "Martial Python"
#             ],
#             "cover_edition_key": "OL26724532M",
#             "cover_i": 8382453,
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL26724532M"
#             ],
#             "first_publish_year": 2011,
#             "has_fulltext": false,
#             "isbn": [
#                 "2889180050",
#                 "9782889180059"
#             ],
#             "key": "/works/OL19068069W",
#             "last_modified_i": 1550803440,
#             "publish_date": [
#                 "Nov 04, 2011"
#             ],
#             "publish_year": [
#                 2011
#             ],
#             "publisher": [
#                 "Parole et Silence Editions"
#             ],
#             "seed": [
#                 "/books/OL26724532M",
#                 "/works/OL19068069W",
#                 "/authors/OL7463482A"
#             ],
#             "text": [
#                 "OL26724532M",
#                 "2889180050",
#                 "9782889180059",
#                 "Martial Python",
#                 "OL7463482A",
#                 "La vie mystique de Marguerite Bays : Stigmatis\u00e9e suisse",
#                 "/works/OL19068069W",
#                 "Parole et Silence Editions"
#             ],
#             "title": "La vie mystique de Marguerite Bays : Stigmatis\u00e9e suisse",
#             "title_suggest": "La vie mystique de Marguerite Bays : Stigmatis\u00e9e suisse",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL12758875M"
#             ],
#             "first_publish_year": 2004,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "2569596"
#             ],
#             "isbn": [
#                 "630645831X",
#                 "9786306458318"
#             ],
#             "key": "/works/OL10053111W",
#             "last_modified_i": 1377047314,
#             "publish_date": [
#                 "March 31, 2004"
#             ],
#             "publish_year": [
#                 2004
#             ],
#             "publisher": [
#                 "EMPIRE MUSIC GROUP"
#             ],
#             "seed": [
#                 "/books/OL12758875M",
#                 "/works/OL10053111W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL12758875M",
#                 "630645831X",
#                 "9786306458318",
#                 "Monty Python",
#                 "OL2693119A",
#                 "Life of Brian-Original Soundtrack",
#                 "/works/OL10053111W",
#                 "EMPIRE MUSIC GROUP",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Life of Brian-Original Soundtrack",
#             "title_suggest": "Life of Brian-Original Soundtrack",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL12645653M"
#             ],
#             "first_publish_year": 2000,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "140543"
#             ],
#             "isbn": [
#                 "6302510775",
#                 "9786302510775"
#             ],
#             "key": "/works/OL10009016W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1400190655,
#             "publish_date": [
#                 "July 31, 2000"
#             ],
#             "publish_year": [
#                 2000
#             ],
#             "publisher": [
#                 "Virgin Records"
#             ],
#             "seed": [
#                 "/books/OL12645653M",
#                 "/works/OL10009016W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL12645653M",
#                 "6302510775",
#                 "9786302510775",
#                 "Monty Python",
#                 "OL2693119A",
#                 "Monty Python Sings",
#                 "/works/OL10009016W",
#                 "Virgin Records",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Monty Python Sings",
#             "title_suggest": "Monty Python Sings",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "cover_edition_key": "OL8984408M",
#             "cover_i": 991022,
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL8984408M"
#             ],
#             "first_publish_year": 1999,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "140551"
#             ],
#             "id_librarything": [
#                 "2081447"
#             ],
#             "isbn": [
#                 "2862746851",
#                 "9782862746852"
#             ],
#             "key": "/works/OL8088568W",
#             "language": [
#                 "fre"
#             ],
#             "last_modified_i": 1303991045,
#             "oclc": [
#                 "586613851"
#             ],
#             "publish_date": [
#                 "November 10, 1999"
#             ],
#             "publish_year": [
#                 1999
#             ],
#             "publisher": [
#                 "Le Cherche-midi Editeur"
#             ],
#             "seed": [
#                 "/books/OL8984408M",
#                 "/works/OL8088568W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL8984408M",
#                 "2862746851",
#                 "9782862746852",
#                 "Monty Python",
#                 "586613851",
#                 "OL2693119A",
#                 "Le grand livre des Monty Python",
#                 "/works/OL8088568W",
#                 "Le Cherche-midi Editeur",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Le grand livre des Monty Python",
#             "title_suggest": "Le grand livre des Monty Python",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL8619610M"
#             ],
#             "first_publish_year": 1974,
#             "has_fulltext": false,
#             "id_librarything": [
#                 "1426358"
#             ],
#             "isbn": [
#                 "1858482747",
#                 "9781858482743"
#             ],
#             "key": "/works/OL8088569W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1400178035,
#             "publish_date": [
#                 "1974"
#             ],
#             "publish_year": [
#                 1974
#             ],
#             "publisher": [
#                 "Listen for Pleasure"
#             ],
#             "seed": [
#                 "/books/OL8619610M",
#                 "/works/OL8088569W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL8619610M",
#                 "1858482747",
#                 "9781858482743",
#                 "Monty Python",
#                 "OL2693119A",
#                 "Monty Python live at Drury Lane",
#                 "/works/OL8088569W",
#                 "Listen for Pleasure",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Monty Python live at Drury Lane",
#             "title_suggest": "Monty Python live at Drury Lane",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL12233084M"
#             ],
#             "first_publish_year": 1996,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "6171199"
#             ],
#             "isbn": [
#                 "1575000164",
#                 "9781575000169"
#             ],
#             "key": "/works/OL8088567W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1400188817,
#             "publish_date": [
#                 "October 1996"
#             ],
#             "publish_year": [
#                 1996
#             ],
#             "publisher": [
#                 "TV Books"
#             ],
#             "seed": [
#                 "/books/OL12233084M",
#                 "/works/OL8088567W",
#                 "/authors/OL2693119A"
#             ],
#             "text": [
#                 "OL12233084M",
#                 "1575000164",
#                 "9781575000169",
#                 "Monty Python",
#                 "OL2693119A",
#                 "and some other garbage from Monty Python",
#                 "The immortal works of William Shakespeare",
#                 "/works/OL8088567W",
#                 "TV Books",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "The immortal works of William Shakespeare",
#             "title_suggest": "The immortal works of William Shakespeare",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Monty Python"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL9723546M"
#             ],
#             "first_publish_year": 1980,
#             "has_fulltext": false,
#             "id_librarything": [
#                 "151350"
#             ],
#             "isbn": [
#                 "9780809280476",
#                 "0809280477"
#             ],
#             "key": "/works/OL8088570W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1281611779,
#             "publish_date": [
#                 "September 1980"
#             ],
#             "publish_year": [
#                 1980
#             ],
#             "publisher": [
#                 "Contemporary Books"
#             ],
#             "seed": [
# ...
#             "cover_i": 7677564,
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL26074586M"
#             ],
#             "first_publish_year": 2010,
#             "has_fulltext": false,
#             "isbn": [
#                 "9781429648844",
#                 "1429648848"
#             ],
#             "key": "/works/OL17487872W",
#             "last_modified_i": 1476450416,
#             "publish_date": [
#                 "2010"
#             ],
#             "publish_year": [
#                 2010
#             ],
#             "publisher": [
#                 "Pebble Plus"
#             ],
#             "seed": [
#                 "/books/OL26074586M",
#                 "/works/OL17487872W",
#                 "/authors/OL2229504A"
#             ],
#             "text": [
#                 "OL26074586M",
#                 "9781429648844",
#                 "1429648848",
#                 "George Wittemyer",
#                 "OL2229504A",
#                 "Pythons",
#                 "/works/OL17487872W",
#                 "Pebble Plus"
#             ],
#             "title": "Pythons",
#             "title_suggest": "Pythons",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL1425365A"
#             ],
#             "author_name": [
#                 "Elizabeth Raum"
#             ],
#             "ddc": [
#                 "597.9678"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL30662383M"
#             ],
#             "first_publish_year": 2014,
#             "has_fulltext": false,
#             "isbn": [
#                 "1607534231",
#                 "9781607533757",
#                 "9781607534235",
#                 "1607533758"
#             ],
#             "key": "/works/OL22642627W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1602999470,
#             "lcc": [
#                 "QL-0666.00000000.O67 R38 2014"
#             ],
#             "lccn": [
#                 "2012045080"
#             ],
#             "publish_date": [
#                 "2014"
#             ],
#             "publish_place": [
#                 "Mankato, Minnesota"
#             ],
#             "publish_year": [
#                 2014
#             ],
#             "publisher": [
#                 "Amicus, high interest"
#             ],
#             "seed": [
#                 "/books/OL30662383M",
#                 "/works/OL22642627W",
#                 "/subjects/juvenile_literature",
#                 "/subjects/pythons",
#                 "/authors/OL1425365A"
#             ],
#             "subject": [
#                 "Juvenile literature",
#                 "Pythons"
#             ],
#             "text": [
#                 "/works/OL22642627W",
#                 "Pythons",
#                 "OL30662383M",
#                 "by Elizabeth Raum",
#                 "2012045080",
#                 "1607534231",
#                 "9781607533757",
#                 "9781607534235",
#                 "1607533758",
#                 "Amicus, high interest",
#                 "OL1425365A",
#                 "Elizabeth Raum",
#                 "Juvenile literature",
#                 "Pythons"
#             ],
#             "title": "Pythons",
#             "title_suggest": "Pythons",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL3402671A"
#             ],
#             "author_name": [
#                 "Steve Chimombo"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 3,
#             "edition_key": [
#                 "OL21700200M",
#                 "OL21700237M",
#                 "OL20875946M"
#             ],
#             "first_publish_year": 1992,
#             "has_fulltext": false,
#             "key": "/works/OL9361421W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1260862239,
#             "publish_date": [
#                 "1992"
#             ],
#             "publish_place": [
#                 "Domasi"
#             ],
#             "publish_year": [
#                 1992
#             ],
#             "publisher": [
#                 "Wasi",
#                 "WASI Publications",
#                 "Wasi Publications"
#             ],
#             "seed": [
#                 "/books/OL21700200M",
#                 "/books/OL21700237M",
#                 "/books/OL20875946M",
#                 "/works/OL9361421W",
#                 "/authors/OL3402671A"
#             ],
#             "text": [
#                 "OL21700200M",
#                 "OL21700237M",
#                 "OL20875946M",
#                 "Steve Chimombo",
#                 "OL3402671A",
#                 "an epic poem",
#                 "[an epic poem]",
#                 "Python! python!",
#                 "/works/OL9361421W",
#                 "Steve Chimombo.",
#                 "Wasi",
#                 "WASI Publications",
#                 "Wasi Publications",
#                 "Python! python"
#             ],
#             "title": "Python! python!",
#             "title_suggest": "Python! python!",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL84272A"
#             ],
#             "author_name": [
#                 "Steve Bernard Miles Chimombo"
#             ],
#             "ddc": [
#                 "821"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL1075204M"
#             ],
#             "first_publish_year": 1992,
#             "has_fulltext": false,
#             "key": "/works/OL946672W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1260379525,
#             "lcc": [
#                 "PR-9385.90000000.C44 P98 1992"
#             ],
#             "lccn": [
#                 "93980576"
#             ],
#             "publish_date": [
#                 "1992"
#             ],
#             "publish_place": [
#                 "Domasi, Malawi"
#             ],
#             "publish_year": [
#                 1992
#             ],
#             "publisher": [
#                 "WASI Publications"
#             ],
#             "seed": [
#                 "/books/OL1075204M",
#                 "/works/OL946672W",
#                 "/authors/OL84272A"
#             ],
#             "text": [
#                 "OL1075204M",
#                 "Steve Bernard Miles Chimombo",
#                 "OL84272A",
#                 "Python! python!",
#                 "/works/OL946672W",
#                 "Steve Chimombo.",
#                 "WASI Publications",
#                 "93980576"
#             ],
#             "title": "Python! python!",
#             "title_suggest": "Python! python!",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL8406316A"
#             ],
#             "author_name": [
#                 "Python Software Guru Publishng"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL29970791M"
#             ],
#             "first_publish_year": 2020,
#             "has_fulltext": false,
#             "isbn": [
#                 "9798633453010"
#             ],
#             "key": "/works/OL21974658W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1599021565,
#             "publish_date": [
#                 "2020"
#             ],
#             "publish_year": [
#                 2020
#             ],
#             "publisher": [
#                 "Independently Published"
#             ],
#             "seed": [
#                 "/books/OL29970791M",
#                 "/works/OL21974658W",
#                 "/authors/OL8406316A"
#             ],
#             "text": [
#                 "OL29970791M",
#                 "9798633453010",
#                 "Python Software Guru Publishng",
#                 "OL8406316A",
#                 "Far Better Than a Throw Away Greeting Card",
#                 "Don't Panic! I'm a Professional Senior Python Software Engineer : Customized 100 Page Lined Notebook Journal Gift for a Busy Senior Python Software Engineer",
#                 "/works/OL21974658W",
#                 "Independently Published"
#             ],
#             "title": "Don't Panic! I'm a Professional Senior Python Software Engineer : Customized 100 Page Lined Notebook Journal Gift for a Busy Senior Python Software Engineer",
#             "title_suggest": "Don't Panic! I'm a Professional Senior Python Software Engineer : Customized 100 Page Lined Notebook Journal Gift for a Busy Senior Python Software Engineer",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "GRAHAM CHAPMAN",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL1820519A",
#                 "OL2693119A"
#             ],
#             "author_name": [
#                 "Graham Chapman",
#                 "Monty Python"
#             ],
#             "contributor": [
#                 "Gary Marsh (Illustrator)",
#                 "John Du Prez (Editor)",
#                 "Terry Gilliam (Illustrator)"
#             ],
#             "cover_edition_key": "OL7480689M",
#             "cover_i": 7278048,
#             "ebook_count_i": 1,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL7480689M"
#             ],
#             "first_publish_year": 2006,
#             "has_fulltext": true,
#             "ia": [
#                 "fairlyincomplete00circ_832"
#             ],
#             "ia_collection_s": "printdisabled;librarygenesis",
#             "id_goodreads": [
#                 "55659"
#             ],
#             "id_librarything": [
#                 "488222"
#             ],
#             "isbn": [
#                 "9780413775290",
#                 "0413775291"
#             ],
#             "key": "/works/OL16817114W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1400176710,
#             "printdisabled_s": "OL7480689M",
#             "public_scan_b": false,
#             "publish_date": [
#                 "2006"
#             ],
#             "publish_place": [
#                 "London"
#             ],
#             "publish_year": [
#                 2006
#             ],
#             "publisher": [
#                 "Methuen Publishing"
#             ],
#             "seed": [
#                 "/books/OL7480689M",
#                 "/works/OL16817114W",
#                 "/authors/OL1820519A",
#                 "/authors/OL2693119A"
#             ],
#             "subject": [
#                 "Accessible book",
#                 "Protected DAISY"
#             ],
#             "text": [
#                 "OL7480689M",
#                 "9780413775290",
#                 "0413775291",
#                 "Graham Chapman",
#                 "Monty Python",
#                 "Gary Marsh (Illustrator)",
#                 "John Du Prez (Editor)",
#                 "Terry Gilliam (Illustrator)",
#                 "fairlyincomplete00circ_832",
#                 "OL1820519A",
#                 "OL2693119A",
#                 "Accessible book",
#                 "Protected DAISY",
#                 "The fairly incomplete & rather badly illustrated Monty Python songbook",
#                 "/works/OL16817114W",
#                 "Methuen Publishing",
#                 "GRAHAM CHAPMAN",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "The fairly incomplete & rather badly illustrated Monty Python songbook",
#             "title_suggest": "The fairly incomplete & rather badly illustrated Monty Python songbook",
#             "type": "work"
#         },
#         {
#             "author_key": [
#                 "OL8487367A"
#             ],
#             "author_name": [
#                 "Python Guru Publishing"
#             ],
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL30238081M"
#             ],
#             "first_publish_year": 2020,
#             "has_fulltext": false,
#             "isbn": [
#                 "9798612711018"
#             ],
#             "key": "/works/OL22190365W",
#             "language": [
#                 "eng"
#             ],
#             "last_modified_i": 1600304986,
#             "publish_date": [
#                 "2020"
#             ],
#             "publish_year": [
#                 2020
#             ],
#             "publisher": [
#                 "Independently Published"
#             ],
#             "seed": [
#                 "/books/OL30238081M",
#                 "/works/OL22190365W",
#                 "/authors/OL8487367A"
#             ],
#             "text": [
#                 "OL30238081M",
#                 "9798612711018",
#                 "Python Guru Publishing",
#                 "OL8487367A",
#                 "Far Better Than a Throw Away Greeting Card",
#                 "Don't Panic! I'm a Professional Senior Python Developer : Customized 100 Page Lined Notebook Journal Gift for a Busy Senior Python Developer",
#                 "/works/OL22190365W",
#                 "Independently Published"
#             ],
#             "title": "Don't Panic! I'm a Professional Senior Python Developer : Customized 100 Page Lined Notebook Journal Gift for a Busy Senior Python Developer",
#             "title_suggest": "Don't Panic! I'm a Professional Senior Python Developer : Customized 100 Page Lined Notebook Journal Gift for a Busy Senior Python Developer",
#             "type": "work"
#         },
#         {
#             "author_alternative_name": [
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "author_key": [
#                 "OL2693119A",
#                 "OL482491A"
#             ],
#             "author_name": [
#                 "Monty Python",
#                 "Arnaud Hofmarcher"
#             ],
#             "cover_edition_key": "OL8939779M",
#             "ebook_count_i": 0,
#             "edition_count": 1,
#             "edition_key": [
#                 "OL8939779M"
#             ],
#             "first_publish_year": 2003,
#             "has_fulltext": false,
#             "id_goodreads": [
#                 "4625476"
#             ],
#             "id_librarything": [
#                 "1813806"
#             ],
#             "isbn": [
#                 "9782749100807",
#                 "2749100801"
#             ],
#             "key": "/works/OL8939779M",
#             "language": [
#                 "fre"
#             ],
#             "last_modified_i": 1604637511,
#             "oclc": [
#                 "470467201"
#             ],
#             "publish_date": [
#                 "February 20, 2003"
#             ],
#             "publish_year": [
#                 2003
#             ],
#             "publisher": [
#                 "Le Cherche-midi Editeur"
#             ],
#             "seed": [
#                 "/books/OL8939779M",
#                 "/works/OL8939779M",
#                 "/authors/OL2693119A",
#                 "/authors/OL482491A"
#             ],
#             "text": [
#                 "OL8939779M",
#                 "9782749100807",
#                 "2749100801",
#                 "Monty Python",
#                 "Arnaud Hofmarcher",
#                 "470467201",
#                 "OL2693119A",
#                 "OL482491A",
#                 "Textes, pens\u00e9es et dialogues de sourd",
#                 "/works/OL8939779M",
#                 "Le Cherche-midi Editeur",
#                 "MONTY PYTHON'S FLYING CIRCUS",
#                 "Monty Python (Comedy troupe)",
#                 "Monty Python's Flying Circus"
#             ],
#             "title": "Textes, pens\u00e9es et dialogues de sourd",
#             "title_suggest": "Textes, pens\u00e9es et dialogues de sourd",
#             "type": "work"
#         }
#     ],
#     "numFound": 1800,
#     "num_found": 1800,
#     "start": 0
# }
